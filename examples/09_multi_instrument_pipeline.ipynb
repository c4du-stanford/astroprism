# %% [markdown]
# # AstroPrism Tutorial: Multi-Instrument Pipeline
#
# This tutorial extends the single-instrument pipeline to jointly fit data from multiple instruments (JWST MIRI + JWST NIRCam) under a shared sky model using Gaussian Processes.
#
# **What you'll learn:**
# 1. Loading and organizing data from multiple instruments into a `MultiInstrumentDataset`
# 2. Building a shared GP sky model across all channels
# 3. Modeling per-channel instrument responses (reprojection + PSF convolution)
# 4. Jointly fitting all instruments with a single likelihood
# 5. Analyzing the posterior across instruments

# %% [markdown]
# ## Environment
#
# To run this tutorial, create a virtual environment and install AstroPrism in editable mode:
#
# ```bash
# cd /path/to/astroprism
#
# # Create and activate a virtual environment
# python3 -m venv .venv
# source .venv/bin/activate
#
# # Install AstroPrism with dev dependencies
# pip install -e ".[dev]"
#
# # Register the Jupyter kernel
# python -m ipykernel install --user --name=astroprism
# ```
#
# Then select the **astroprism** kernel in Jupyter or VS Code.

# %% [markdown]
# ## Imports

# %%
import sys
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import warnings
from astropy.utils.exceptions import AstropyWarning

import jax
import jax.numpy as jnp
import jax.random as jr
import nifty8.re as jft

warnings.filterwarnings('ignore', category=AstropyWarning)

# %% [markdown]
# ### 1. Data Loading
#
# `load_multiple_datasets` takes a dict mapping instrument keys to data paths and returns a `MultiInstrumentDataset`. Channel keys are prefixed as `instrument:channel` (e.g. `JWST_MIRI:f770w`).

# %%
# Imports
from astroprism.io import load_multiple_datasets, MultiInstrumentDataset

# Load Multi-Instrument Dataset
paths = {
    "HERSCHEL_PACS":   "../data/tutorial/herschel_pacs/", # _cutout works too
    "HERSCHEL_SPIRE": "../data/tutorial/herschel_spire/",
}
dataset = load_multiple_datasets(paths_dict=paths, extension="fits")
print(dataset.summary())

# Plot Data — one panel per channel, labelled by instrument:channel
n = dataset.n_channels
fig, axes = plt.subplots(1, n, figsize=(4*n, 4))
for i, key in enumerate(dataset.channel_keys):
    data, wcs, psf = dataset[key]
    axes[i].imshow(data, norm=LogNorm(), origin='lower')
    axes[i].set_title(key, fontsize=8)
plt.suptitle("Data (multi-instrument)")
plt.tight_layout()
plt.show()

# Plot PSFs
fig, axes = plt.subplots(1, n, figsize=(4*n, 4))
for i, key in enumerate(dataset.channel_keys):
    _, _, psf = dataset[key]
    axes[i].imshow(psf, norm=LogNorm(), origin='lower')
    axes[i].set_title(key, fontsize=8)
plt.suptitle("PSF (multi-instrument)")
plt.tight_layout()
plt.show()
# Out:
# MultiInstrumentDataset Summary:
# --------------------------------
# Number of instruments: 2
# Instrument keys: ['HERSCHEL_PACS', 'HERSCHEL_SPIRE']
# Number of channels: 6
# Channel keys: ['HERSCHEL_PACS:herschel_ngc1566_pacs100', 'HERSCHEL_PACS:herschel_ngc1566_pacs160', 'HERSCHEL_PACS:herschel_ngc1566_pacs70', 'HERSCHEL_SPIRE:herschel_ngc1566_spire250', 'HERSCHEL_SPIRE:herschel_ngc1566_spire350', 'HERSCHEL_SPIRE:herschel_ngc1566_spire500']
# Channel shapes: [(506, 540), (313, 335), (608, 644), (365, 359), (271, 265), (188, 184)]
# Pixel scales: [(1.6999992, 1.6999992), (2.8500012, 2.8500012), (1.4000004000000001, 1.4000004000000001), (4.5, 4.5), (6.249995999999999, 6.249995999999999), (9.0, 9.0)]

# %%
from astroprism.io import SingleInstrumentDataset

# Keep only the first 2 channels per instrument for quick testing
n_keep = 2
trimmed = {}
for key, ds in dataset.instrument_datasets.items():
    trimmed[key] = SingleInstrumentDataset(
        data=ds.data[:n_keep],
        wcs=ds.wcs[:n_keep],
        psfs=ds.psfs[:n_keep],
        channel_keys=ds.channel_keys[:n_keep],
    )
dataset = MultiInstrumentDataset(instrument_datasets=trimmed)
print(dataset.summary())


# Plot Data — one panel per channel, labelled by instrument:channel
n = dataset.n_channels
fig, axes = plt.subplots(1, n, figsize=(4*n, 4))
for i, key in enumerate(dataset.channel_keys):
    data, wcs, psf = dataset[key]
    axes[i].imshow(data, norm=LogNorm(), origin='lower')
    axes[i].set_title(key, fontsize=8)
plt.suptitle("Data (multi-instrument)")
plt.tight_layout()
plt.show()
# Out:
# MultiInstrumentDataset Summary:
# --------------------------------
# Number of instruments: 2
# Instrument keys: ['HERSCHEL_PACS', 'HERSCHEL_SPIRE']
# Number of channels: 4
# Channel keys: ['HERSCHEL_PACS:herschel_ngc1566_pacs100', 'HERSCHEL_PACS:herschel_ngc1566_pacs160', 'HERSCHEL_SPIRE:herschel_ngc1566_spire250', 'HERSCHEL_SPIRE:herschel_ngc1566_spire350']
# Channel shapes: [(506, 540), (313, 335), (365, 359), (271, 265)]
# Pixel scales: [(1.6999992, 1.6999992), (2.8500012, 2.8500012), (4.5, 4.5), (6.249995999999999, 6.249995999999999)]

# %%
# import copy
# import numpy as np
# from astropy.wcs.utils import pixel_to_pixel

# # Crop all channels to the same sky position (MIRI image center), at each
# # instrument's native pixel resolution.
# #
# # NOTE: NIRCam's pixel scale is ~3.5x finer than MIRI, so the same sky area
# # contains ~12x more pixels. For quick CPU testing use crop_size ~ 256-512.
# # For full-resolution multi-instrument fitting, a GPU is recommended.

# crop_size = 512   # pixels per side — adjust for speed vs coverage trade-off

# miri_ref = dataset.get_instrument_dataset("JWST_MIRI")
# ref_wcs   = miri_ref.wcs[0]
# ref_ny, ref_nx = miri_ref.shapes[0]
# ref_cx, ref_cy = (ref_nx - 1) / 2.0, (ref_ny - 1) / 2.0

# def crop_channel(data, wcs, crop_size, ref_wcs, ref_cx, ref_cy):
#     """Center-crop around the sky position (ref_cx, ref_cy) in ref_wcs."""
#     ny, nx = data.shape
#     px, py = pixel_to_pixel(ref_wcs, wcs, ref_cx, ref_cy)
#     cx, cy = int(round(float(px))), int(round(float(py)))
#     half = crop_size // 2
#     x0 = min(max(cx - half, 0), max(nx - crop_size, 0))
#     y0 = min(max(cy - half, 0), max(ny - crop_size, 0))
#     data_crop = data[y0:y0+crop_size, x0:x0+crop_size]
#     wcs_crop = copy.deepcopy(wcs)
#     wcs_crop.wcs.crpix[0] -= x0
#     wcs_crop.wcs.crpix[1] -= y0
#     wcs_crop.array_shape = data_crop.shape
#     return data_crop, wcs_crop

# cropped = {}
# for key, ds in dataset.instrument_datasets.items():
#     data_list, wcs_list = [], []
#     for d, w in zip(ds.data, ds.wcs):
#         dc, wc = crop_channel(d, w, crop_size, ref_wcs, ref_cx, ref_cy)
#         data_list.append(dc)
#         wcs_list.append(wc)
#     cropped[key] = SingleInstrumentDataset(
#         data=data_list,
#         wcs=wcs_list,
#         psfs=ds.psfs,
#         channel_keys=ds.channel_keys,
#     )
# dataset = MultiInstrumentDataset(instrument_datasets=cropped)
# print(dataset.summary())

# # Plot cropped data — pixel coordinates
# n = dataset.n_channels
# fig, axes = plt.subplots(1, n, figsize=(4*n, 4))
# for i, key in enumerate(dataset.channel_keys):
#     data, _, _ = dataset[key]
#     axes[i].imshow(data, norm=LogNorm(), origin='lower')
#     axes[i].set_title(f"{key}\n{data.shape}", fontsize=8)
# plt.suptitle("Cropped Data (pixel)")
# plt.tight_layout()
# plt.show()

# # Plot cropped data — sky projection (RA/Dec)
# fig = plt.figure(figsize=(4*n, 4))
# for i, key in enumerate(dataset.channel_keys):
#     data, wcs, _ = dataset[key]
#     ax = fig.add_subplot(1, n, i+1, projection=wcs)
#     ax.imshow(data, norm=LogNorm(), origin='lower')
#     ax.coords[0].set_axislabel("RA")
#     ax.coords[1].set_axislabel("Dec")
#     ax.coords[1].set_ticklabel_visible(i == 0)
#     ax.set_title(key, fontsize=8)
# plt.suptitle("Cropped Data (sky)")
# plt.tight_layout()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 14
#       5 # Crop all channels to the same sky position (MIRI image center), at each
#       6 # instrument's native pixel resolution.
#       7 #
#       8 # NOTE: NIRCam's pixel scale is ~3.5x finer than MIRI, so the same sky area
#       9 # contains ~12x more pixels. For quick CPU testing use crop_size ~ 256-512.
#      10 # For full-resolution multi-instrument fitting, a GPU is recommended.
#      12 crop_size = 512   # pixels per side — adjust for speed vs coverage trade-off
# ---> 14 miri_ref = dataset.get_instrument_dataset("JWST_MIRI")
#      15 ref_wcs   = miri_ref.wcs[0]
#      16 ref_ny, ref_nx = miri_ref.shapes[0]
#
# File ~/Desktop/projects/AstroGP/astroprism/src/astroprism/io/dataset.py:285, in MultiInstrumentDataset.get_instrument_dataset(self, instrument_key)
#     284 def get_instrument_dataset(self, instrument_key: str) -> SingleInstrumentDataset:
# --> 285     return self.instrument_datasets[instrument_key]
#
# KeyError: 'JWST_MIRI'

# %% [markdown]
# ### 2. Set Up GP Prior
#
# The sky model is defined on a single reference frame shared across all instruments. We choose the first MIRI channel as the reference (coarsest resolution). NIRCam channels are reprojected onto this frame in step 3.
#
# `SpatialGP` is built on the reference shape/pixel-scale; `MixtureGP` mixes across all `n_channels`.

# %%
# Imports
from astroprism.models.gp import SpatialGP, MixtureGP

# Use the first MIRI channel as the reference sky frame
miri_ds = dataset.get_instrument_dataset("HERSCHEL_PACS")
signal_wcs   = miri_ds.wcs[0]
signal_shape = miri_ds.shapes[0]

# SpatialGP: correlated field on the sky reference frame
spatial_gp = SpatialGP(
    n_channels=dataset.n_channels,
    shape=signal_shape,
    distances=miri_ds.pixel_scales[0],
)

# MixtureGP: linear mixing across all channels (MIRI + NIRCam)
mixture = MixtureGP(spatial_gps=spatial_gp)

print("MixtureGP domain keys:", list(mixture.domain.keys()))
print(f"Sky model shape: {signal_shape}, n_channels: {dataset.n_channels}")
# Out:
# MixtureGP domain keys: ['zeromode', 'fluctuations', 'loglogavgslope', 'spectrum', 'flexibility', 'xi', 'mixture_matrix', 'mixing_offset']
# Sky model shape: (506, 540), n_channels: 4

# %% [markdown]
# ### 3. Set Up the Instrument Response Model
#
# `InstrumentResponse` accepts the full `MultiInstrumentDataset` directly — it builds one reprojector and one convolver per channel, regardless of which instrument the channel belongs to.

# %%
# Imports
from astroprism.models.response import InstrumentResponse

# Instrument Response: one reprojector + convolver per channel
response = InstrumentResponse(
    dataset=dataset,
    signal_wcs=signal_wcs,
    signal_shape=signal_shape,
)

print("InstrumentResponse domain keys:", list(response.domain.keys()))
# Out:
# InstrumentResponse domain keys: ['psf_sigma', 'psf_rotation']

# %% [markdown]
# ### 4. Set Up the Noise Model

# %%
# Imports
from astroprism.models.noise import NoiseModel

# NoiseModel: one noise level per channel
noise = NoiseModel(n_channels=dataset.n_channels)

print("NoiseModel domain keys:", list(noise.domain.keys()))
# Out:
# NoiseModel domain keys: ['background_std', 'poisson_scale']

# %% [markdown]
# ### 5. Set Up the Forward Model

# %%
# Imports
from astroprism.models.forward import ForwardModel

# ForwardModel: sky → reprojection → PSF convolution → noise
model = ForwardModel(mixture, response, noise)

print("ForwardModel domain keys:", list(model.domain.keys()))
# Out:
# ForwardModel domain keys: ['zeromode', 'fluctuations', 'loglogavgslope', 'spectrum', 'flexibility', 'xi', 'mixture_matrix', 'mixing_offset', 'psf_sigma', 'psf_rotation', 'background_std', 'poisson_scale']

# %% [markdown]
# ### 6. Set Up the Likelihood and Run Inference
#
# The likelihood is built over all channels from both instruments simultaneously — the joint fit.

# %%
# Imports
from astroprism.models.likelihood import build_likelihood
from astroprism.inference.vi import run_inference

# Joint likelihood across all MIRI + NIRCam channels
likelihood = build_likelihood(dataset, model, mask=dataset.readout)

# Run inference
samples, state = run_inference(
    likelihood,
    n_iterations=10,
    n_samples=2,
    seed=42,
    output_directory="tutorial_results_multi"
)
# Out:
# /opt/homebrew/Cellar/python@3.14/3.14.0_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/genericpath.py:39: RuntimeWarning: bool is used as a file descriptor
#   st = os.stat(path)
# OPTIMIZE_KL: Starting 0001
# Starting VI optimization: 10 iterations, 2 samples.
# linear_solver: Iteration 0 ⛰:+6.0844e+08 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:+4.0272e+07 Δ⛰:5.6817e+08 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:+1.0109e+07 Δ⛰:3.0163e+07 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:+5.1208e+06 Δ⛰:4.9880e+06 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:+2.7595e+06 Δ⛰:2.3613e+06 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:+2.4602e+06 Δ⛰:2.9934e+05 ➽:1.0000e-04
# linear_solver: Iteration 6 ⛰:+2.0128e+06 Δ⛰:4.4741e+05 ➽:1.0000e-04
# linear_solver: Iteration 7 ⛰:+1.1194e+06 Δ⛰:8.9338e+05 ➽:1.0000e-04
# linear_solver: Iteration 8 ⛰:+6.6020e+05 Δ⛰:4.5921e+05 ➽:1.0000e-04
# linear_solver: Iteration 9 ⛰:+4.8638e+05 Δ⛰:1.7381e+05 ➽:1.0000e-04
# linear_solver: Iteration 10 ⛰:+3.6118e+05 Δ⛰:1.2520e+05 ➽:1.0000e-04
# linear_solver: Iteration 11 ⛰:-8.1558e+04 Δ⛰:4.4274e+05 ➽:1.0000e-04
# linear_solver: Iteration 12 ⛰:-1.4106e+05 Δ⛰:5.9501e+04 ➽:1.0000e-04
# linear_solver: Iteration 13 ⛰:-1.4293e+05 Δ⛰:1.8713e+03 ➽:1.0000e-04
# linear_solver: Iteration 14 ⛰:-2.5428e+05 Δ⛰:1.1135e+05 ➽:1.0000e-04
# linear_solver: Iteration 15 ⛰:-3.2025e+05 Δ⛰:6.5967e+04 ➽:1.0000e-04
# linear_solver: Iteration 16 ⛰:-3.3877e+05 Δ⛰:1.8521e+04 ➽:1.0000e-04
# linear_solver: Iteration 17 ⛰:-4.2760e+05 Δ⛰:8.8832e+04 ➽:1.0000e-04
# linear_solver: Iteration 18 ⛰:-4.7798e+05 Δ⛰:5.0376e+04 ➽:1.0000e-04
# linear_solver: Iteration 19 ⛰:-4.7895e+05 Δ⛰:9.7145e+02 ➽:1.0000e-04
# linear_solver: Iteration 20 ⛰:-4.8416e+05 Δ⛰:5.2088e+03 ➽:1.0000e-04
# linear_solver: Iteration 21 ⛰:-5.2675e+05 Δ⛰:4.2587e+04 ➽:1.0000e-04
# linear_solver: Iteration 22 ⛰:-5.2826e+05 Δ⛰:1.5102e+03 ➽:1.0000e-04
# linear_solver: Iteration 23 ⛰:-5.7603e+05 Δ⛰:4.7771e+04 ➽:1.0000e-04
# linear_solver: Iteration 24 ⛰:-5.7634e+05 Δ⛰:3.1258e+02 ➽:1.0000e-04
# linear_solver: Iteration 25 ⛰:-5.8291e+05 Δ⛰:6.5689e+03 ➽:1.0000e-04
# linear_solver: Iteration 26 ⛰:-6.0151e+05 Δ⛰:1.8599e+04 ➽:1.0000e-04
# linear_solver: Iteration 27 ⛰:-6.0252e+05 Δ⛰:1.0151e+03 ➽:1.0000e-04
# linear_solver: Iteration 28 ⛰:-6.0803e+05 Δ⛰:5.5065e+03 ➽:1.0000e-04
# linear_solver: Iteration 29 ⛰:-6.2658e+05 Δ⛰:1.8554e+04 ➽:1.0000e-04
# linear_solver: Iteration 30 ⛰:-6.3009e+05 Δ⛰:3.5043e+03 ➽:1.0000e-04
# linear_solver: Iteration 31 ⛰:-6.4617e+05 Δ⛰:1.6079e+04 ➽:1.0000e-04
# linear_solver: Iteration 88 ⛰:-7.9324e+05 Δ⛰:1.0559e+03 ➽:1.0000e-04
# linear_solver: Iteration 89 ⛰:-7.9330e+05 Δ⛰:6.7722e+01 ➽:1.0000e-04
# linear_solver: Iteration 90 ⛰:-7.9542e+05 Δ⛰:2.1117e+03 ➽:1.0000e-04
# linear_solver: Iteration 91 ⛰:-7.9554e+05 Δ⛰:1.2569e+02 ➽:1.0000e-04
# linear_solver: Iteration 92 ⛰:-7.9569e+05 Δ⛰:1.5326e+02 ➽:1.0000e-04
# linear_solver: Iteration 93 ⛰:-7.9720e+05 Δ⛰:1.5024e+03 ➽:1.0000e-04
# linear_solver: Iteration 94 ⛰:-7.9734e+05 Δ⛰:1.4025e+02 ➽:1.0000e-04
# linear_solver: Iteration 95 ⛰:-7.9736e+05 Δ⛰:2.0170e+01 ➽:1.0000e-04
# linear_solver: Iteration 96 ⛰:-7.9737e+05 Δ⛰:1.4858e+01 ➽:1.0000e-04
# linear_solver: Iteration 97 ⛰:-7.9797e+05 Δ⛰:5.9665e+02 ➽:1.0000e-04
# linear_solver: Iteration 98 ⛰:-7.9800e+05 Δ⛰:3.1615e+01 ➽:1.0000e-04
# linear_solver: Iteration 99 ⛰:-7.9917e+05 Δ⛰:1.1673e+03 ➽:1.0000e-04
# linear_solver: Iteration ✖✖✖ (100) ⛰:-7.9940e+05 Δ⛰:2.3146e+02 ➽:1.0000e-04
# linear_solver: Iteration 0 ⛰:+1.4222e+08 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:+1.2278e+08 Δ⛰:1.9442e+07 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:+2.9650e+07 Δ⛰:9.3131e+07 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:+3.0439e+06 Δ⛰:2.6606e+07 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:+2.1476e+06 Δ⛰:8.9622e+05 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:+1.5504e+06 Δ⛰:5.9724e+05 ➽:1.0000e-04
# linear_solver: Iteration 6 ⛰:+1.3451e+06 Δ⛰:2.0528e+05 ➽:1.0000e-04
# linear_solver: Iteration 7 ⛰:+1.0732e+06 Δ⛰:2.7191e+05 ➽:1.0000e-04
# linear_solver: Iteration 8 ⛰:+1.0533e+06 Δ⛰:1.9872e+04 ➽:1.0000e-04
# linear_solver: Iteration 9 ⛰:+5.4907e+05 Δ⛰:5.0428e+05 ➽:1.0000e-04
# linear_solver: Iteration 10 ⛰:+2.3768e+05 Δ⛰:3.1139e+05 ➽:1.0000e-04
# linear_solver: Iteration 11 ⛰:+7.9806e+04 Δ⛰:1.5787e+05 ➽:1.0000e-04
# linear_solver: Iteration 12 ⛰:-2.2866e+04 Δ⛰:1.0267e+05 ➽:1.0000e-04
# linear_solver: Iteration 13 ⛰:-1.9845e+05 Δ⛰:1.7559e+05 ➽:1.0000e-04
# linear_solver: Iteration 14 ⛰:-1.9868e+05 Δ⛰:2.2494e+02 ➽:1.0000e-04
# linear_solver: Iteration 15 ⛰:-2.6741e+05 Δ⛰:6.8736e+04 ➽:1.0000e-04
# linear_solver: Iteration 16 ⛰:-3.2252e+05 Δ⛰:5.5102e+04 ➽:1.0000e-04
# linear_solver: Iteration 17 ⛰:-3.9633e+05 Δ⛰:7.3812e+04 ➽:1.0000e-04
# linear_solver: Iteration 18 ⛰:-4.7791e+05 Δ⛰:8.1583e+04 ➽:1.0000e-04
# linear_solver: Iteration 19 ⛰:-4.7804e+05 Δ⛰:1.2755e+02 ➽:1.0000e-04
# linear_solver: Iteration 20 ⛰:-4.8093e+05 Δ⛰:2.8954e+03 ➽:1.0000e-04
# linear_solver: Iteration 21 ⛰:-5.1287e+05 Δ⛰:3.1936e+04 ➽:1.0000e-04
# linear_solver: Iteration 22 ⛰:-5.1720e+05 Δ⛰:4.3329e+03 ➽:1.0000e-04
# linear_solver: Iteration 23 ⛰:-5.5277e+05 Δ⛰:3.5564e+04 ➽:1.0000e-04
# linear_solver: Iteration 24 ⛰:-5.7453e+05 Δ⛰:2.1764e+04 ➽:1.0000e-04
# linear_solver: Iteration 25 ⛰:-5.7457e+05 Δ⛰:3.5619e+01 ➽:1.0000e-04
# linear_solver: Iteration 26 ⛰:-5.8674e+05 Δ⛰:1.2175e+04 ➽:1.0000e-04
# linear_solver: Iteration 27 ⛰:-6.1907e+05 Δ⛰:3.2331e+04 ➽:1.0000e-04
# linear_solver: Iteration 28 ⛰:-6.3070e+05 Δ⛰:1.1625e+04 ➽:1.0000e-04
# linear_solver: Iteration 29 ⛰:-6.4848e+05 Δ⛰:1.7784e+04 ➽:1.0000e-04
# linear_solver: Iteration 30 ⛰:-6.4857e+05 Δ⛰:9.2092e+01 ➽:1.0000e-04
# linear_solver: Iteration 31 ⛰:-6.6631e+05 Δ⛰:1.7739e+04 ➽:1.0000e-04
# linear_solver: Iteration 32 ⛰:-6.6996e+05 Δ⛰:3.6456e+03 ➽:1.0000e-04
# linear_solver: Iteration 33 ⛰:-6.8418e+05 Δ⛰:1.4220e+04 ➽:1.0000e-04
# linear_solver: Iteration 34 ⛰:-6.8753e+05 Δ⛰:3.3548e+03 ➽:1.0000e-04
# linear_solver: Iteration 35 ⛰:-6.8827e+05 Δ⛰:7.3961e+02 ➽:1.0000e-04
# linear_solver: Iteration 36 ⛰:-6.8900e+05 Δ⛰:7.2618e+02 ➽:1.0000e-04
# linear_solver: Iteration 37 ⛰:-7.0080e+05 Δ⛰:1.1806e+04 ➽:1.0000e-04
# linear_solver: Iteration 38 ⛰:-7.0145e+05 Δ⛰:6.4890e+02 ➽:1.0000e-04
# linear_solver: Iteration 39 ⛰:-7.0277e+05 Δ⛰:1.3184e+03 ➽:1.0000e-04
# linear_solver: Iteration 40 ⛰:-7.0327e+05 Δ⛰:4.9624e+02 ➽:1.0000e-04
# linear_solver: Iteration 41 ⛰:-7.0394e+05 Δ⛰:6.7517e+02 ➽:1.0000e-04
# linear_solver: Iteration 98 ⛰:-7.9963e+05 Δ⛰:9.5556e+02 ➽:1.0000e-04
# linear_solver: Iteration 99 ⛰:-8.0005e+05 Δ⛰:4.2277e+02 ➽:1.0000e-04
# linear_solver: Iteration ✖✖✖ (100) ⛰:-8.0032e+05 Δ⛰:2.7522e+02 ➽:1.0000e-04
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:1.528018e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+4.399731e+12 Δ⛰:2.040907e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:5.221534e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+8.360550e+11 Δ⛰:3.563676e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:2.501825e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+2.043219e+11 Δ⛰:6.317332e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:1.032262e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+7.649675e+10 Δ⛰:1.278251e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:1.516574e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+6.155852e+12 Δ⛰:1.448397e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:6.354428e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+1.271878e+12 Δ⛰:4.883974e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:4.879279e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+2.777915e+11 Δ⛰:9.940865e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:3.851040e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+1.120101e+11 Δ⛰:1.657814e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:2.108092e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 5 ⛰:+6.718655e+10 Δ⛰:4.482352e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:36 |↘|:1.543891e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 6 ⛰:+5.121346e+10 Δ⛰:1.597309e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:8.712806e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+1.431578e+14 Δ⛰:2.750154e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:5.684011e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+3.414140e+13 Δ⛰:1.090164e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:4.249191e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+8.207326e+12 Δ⛰:2.593407e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:1.984405e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+2.084058e+12 Δ⛰:6.123268e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:7.339334e+01 🞋:1.643660e+02
# nonlinear_solver: Iteration 5 ⛰:+5.737875e+11 Δ⛰:1.510270e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:4.068559e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+2.560564e+14 Δ⛰:2.577504e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:1.033229e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+5.948147e+13 Δ⛰:1.965749e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:5.781849e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+1.431219e+13 Δ⛰:4.516928e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:3.274210e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+3.398946e+12 Δ⛰:1.091325e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:1.639363e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 5 ⛰:+8.453094e+11 Δ⛰:2.553637e+12
# kl_minimizer: →:1.0 ↺:True #∇²:72 |↘|:9.554973e+01 🞋:1.643660e+02
# kl_minimizer: Iteration 1 ⛰:+3.792045e+07 Δ⛰:9.901073e+07 🞋:1.000000e-04
# OPTIMIZE_KL: Iteration 0001 ⛰:+3.7920e+07
# OPTIMIZE_KL: #(Nonlinear sampling steps) (4, 6, 5, 5)
# OPTIMIZE_KL: #(KL minimization steps) 1
# OPTIMIZE_KL: Likelihood residual(s):
# 'reduced χ²: 4.3e+02± 1.6e+02, avg: -1.1e+01±     2.7, #dof: 162412'
#
# OPTIMIZE_KL: Prior residual(s):
# background_std          :: 'reduced χ²: 8.7e+01±     1.3, avg:     +4.9±    0.57, #dof:      4'
# flexibility             :: 'reduced χ²:     2.2±     1.3, avg:    -0.46±    0.14, #dof:      4'
# fluctuations            :: 'reduced χ²:     3.5±    0.72, avg:     -1.1±    0.16, #dof:      4'
# loglogavgslope          :: 'reduced χ²:     2.4±    0.32, avg:   +0.093±    0.14, #dof:      4'
# mixing_offset           :: 'reduced χ²:     1.7±     1.1, avg:    -0.43±    0.85, #dof:      4'
# mixture_matrix          :: 'reduced χ²:     1.8±    0.41, avg:     +0.5±   0.093, #dof:     16'
# poisson_scale           :: 'reduced χ²:    0.53±    0.12, avg:    +0.34±   0.034, #dof:      4'
# psf_rotation            :: 'reduced χ²:     2.3±    0.58, avg:     -0.3±    0.65, #dof:      4'
# psf_sigma               :: 'reduced χ²:     2.1±     1.3, avg:    +0.22±    0.39, #dof:      4'
# spectrum                :: 'reduced χ²:     2.0±  0.0011, avg: -0.00022± 0.00055, #dof: 550648'
# xi                      :: 'reduced χ²:     2.0± 0.00085, avg:  +0.0018± 0.00097, #dof:1092960'
# zeromode                :: 'reduced χ²:     1.5±    0.87, avg:   -0.065±    0.73, #dof:      4'
#
#
# OPTIMIZE_KL: Starting 0002
# linear_solver: Iteration 0 ⛰:+6.9272e+07 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:+2.2645e+07 Δ⛰:4.6627e+07 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:+2.1036e+07 Δ⛰:1.6088e+06 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:+1.8730e+07 Δ⛰:2.3068e+06 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:+1.6177e+07 Δ⛰:2.5523e+06 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:+1.2627e+07 Δ⛰:3.5499e+06 ➽:1.0000e-04
# linear_solver: Iteration 6 ⛰:+9.9095e+06 Δ⛰:2.7179e+06 ➽:1.0000e-04
# linear_solver: Iteration 7 ⛰:+8.2911e+06 Δ⛰:1.6184e+06 ➽:1.0000e-04
# linear_solver: Iteration 8 ⛰:+6.9939e+06 Δ⛰:1.2972e+06 ➽:1.0000e-04
# linear_solver: Iteration 9 ⛰:+6.6106e+06 Δ⛰:3.8328e+05 ➽:1.0000e-04
# linear_solver: Iteration 10 ⛰:+6.0397e+06 Δ⛰:5.7086e+05 ➽:1.0000e-04
# linear_solver: Iteration 11 ⛰:+4.9493e+06 Δ⛰:1.0904e+06 ➽:1.0000e-04
# linear_solver: Iteration 12 ⛰:+3.8555e+06 Δ⛰:1.0938e+06 ➽:1.0000e-04
# linear_solver: Iteration 13 ⛰:+2.7399e+06 Δ⛰:1.1156e+06 ➽:1.0000e-04
# linear_solver: Iteration 14 ⛰:+2.1080e+06 Δ⛰:6.3189e+05 ➽:1.0000e-04
# linear_solver: Iteration 15 ⛰:+2.0843e+06 Δ⛰:2.3649e+04 ➽:1.0000e-04
# linear_solver: Iteration 16 ⛰:+2.0600e+06 Δ⛰:2.4386e+04 ➽:1.0000e-04
# linear_solver: Iteration 17 ⛰:+1.5909e+06 Δ⛰:4.6910e+05 ➽:1.0000e-04
# linear_solver: Iteration 18 ⛰:+1.2618e+06 Δ⛰:3.2903e+05 ➽:1.0000e-04
# linear_solver: Iteration 19 ⛰:+9.4513e+05 Δ⛰:3.1670e+05 ➽:1.0000e-04
# linear_solver: Iteration 20 ⛰:+8.2741e+05 Δ⛰:1.1772e+05 ➽:1.0000e-04
# linear_solver: Iteration 21 ⛰:+7.8339e+05 Δ⛰:4.4015e+04 ➽:1.0000e-04
# linear_solver: Iteration 22 ⛰:+6.5415e+05 Δ⛰:1.2924e+05 ➽:1.0000e-04
# linear_solver: Iteration 23 ⛰:+6.3663e+05 Δ⛰:1.7525e+04 ➽:1.0000e-04
# linear_solver: Iteration 24 ⛰:+5.3196e+05 Δ⛰:1.0466e+05 ➽:1.0000e-04
# linear_solver: Iteration 25 ⛰:+4.7562e+05 Δ⛰:5.6345e+04 ➽:1.0000e-04
# linear_solver: Iteration 26 ⛰:+4.4961e+05 Δ⛰:2.6004e+04 ➽:1.0000e-04
# linear_solver: Iteration 27 ⛰:+4.1496e+05 Δ⛰:3.4653e+04 ➽:1.0000e-04
# linear_solver: Iteration 28 ⛰:+4.0948e+05 Δ⛰:5.4849e+03 ➽:1.0000e-04
# linear_solver: Iteration 29 ⛰:+3.1078e+05 Δ⛰:9.8696e+04 ➽:1.0000e-04
# linear_solver: Iteration 30 ⛰:+1.8582e+05 Δ⛰:1.2496e+05 ➽:1.0000e-04
# linear_solver: Iteration 31 ⛰:+1.0915e+05 Δ⛰:7.6668e+04 ➽:1.0000e-04
# linear_solver: Iteration 32 ⛰:+7.1407e+04 Δ⛰:3.7746e+04 ➽:1.0000e-04
# linear_solver: Iteration 33 ⛰:+7.1218e+04 Δ⛰:1.8955e+02 ➽:1.0000e-04
# linear_solver: Iteration 62 ⛰:-5.1746e+05 Δ⛰:2.4522e+03 ➽:1.0000e-04
# linear_solver: Iteration 63 ⛰:-5.2260e+05 Δ⛰:5.1347e+03 ➽:1.0000e-04
# linear_solver: Iteration 64 ⛰:-5.2277e+05 Δ⛰:1.6824e+02 ➽:1.0000e-04
# linear_solver: Iteration 65 ⛰:-5.2355e+05 Δ⛰:7.8325e+02 ➽:1.0000e-04
# linear_solver: Iteration 66 ⛰:-5.4094e+05 Δ⛰:1.7390e+04 ➽:1.0000e-04
# linear_solver: Iteration 67 ⛰:-5.4248e+05 Δ⛰:1.5454e+03 ➽:1.0000e-04
# linear_solver: Iteration 68 ⛰:-5.6120e+05 Δ⛰:1.8716e+04 ➽:1.0000e-04
# linear_solver: Iteration 69 ⛰:-5.6547e+05 Δ⛰:4.2729e+03 ➽:1.0000e-04
# linear_solver: Iteration 70 ⛰:-5.7216e+05 Δ⛰:6.6916e+03 ➽:1.0000e-04
# linear_solver: Iteration 71 ⛰:-5.8038e+05 Δ⛰:8.2187e+03 ➽:1.0000e-04
# linear_solver: Iteration 72 ⛰:-5.9511e+05 Δ⛰:1.4723e+04 ➽:1.0000e-04
# linear_solver: Iteration 73 ⛰:-6.0117e+05 Δ⛰:6.0608e+03 ➽:1.0000e-04
# linear_solver: Iteration 74 ⛰:-6.0193e+05 Δ⛰:7.6315e+02 ➽:1.0000e-04
# linear_solver: Iteration 75 ⛰:-6.0217e+05 Δ⛰:2.3616e+02 ➽:1.0000e-04
# linear_solver: Iteration 76 ⛰:-6.1129e+05 Δ⛰:9.1250e+03 ➽:1.0000e-04
# linear_solver: Iteration 77 ⛰:-6.1400e+05 Δ⛰:2.7051e+03 ➽:1.0000e-04
# linear_solver: Iteration 78 ⛰:-6.1797e+05 Δ⛰:3.9780e+03 ➽:1.0000e-04
# linear_solver: Iteration 79 ⛰:-6.1888e+05 Δ⛰:9.0418e+02 ➽:1.0000e-04
# linear_solver: Iteration 80 ⛰:-6.2633e+05 Δ⛰:7.4550e+03 ➽:1.0000e-04
# linear_solver: Iteration 81 ⛰:-6.3150e+05 Δ⛰:5.1688e+03 ➽:1.0000e-04
# linear_solver: Iteration 82 ⛰:-6.3233e+05 Δ⛰:8.3240e+02 ➽:1.0000e-04
# linear_solver: Iteration 83 ⛰:-6.3242e+05 Δ⛰:8.8770e+01 ➽:1.0000e-04
# linear_solver: Iteration 84 ⛰:-6.3336e+05 Δ⛰:9.3931e+02 ➽:1.0000e-04
# linear_solver: Iteration 85 ⛰:-6.4319e+05 Δ⛰:9.8267e+03 ➽:1.0000e-04
# linear_solver: Iteration 86 ⛰:-6.4335e+05 Δ⛰:1.5823e+02 ➽:1.0000e-04
# linear_solver: Iteration 87 ⛰:-6.5192e+05 Δ⛰:8.5731e+03 ➽:1.0000e-04
# linear_solver: Iteration 88 ⛰:-6.5699e+05 Δ⛰:5.0685e+03 ➽:1.0000e-04
# linear_solver: Iteration 89 ⛰:-6.5700e+05 Δ⛰:7.4409e+00 ➽:1.0000e-04
# linear_solver: Iteration 90 ⛰:-6.6553e+05 Δ⛰:8.5326e+03 ➽:1.0000e-04
# linear_solver: Iteration 91 ⛰:-6.6654e+05 Δ⛰:1.0071e+03 ➽:1.0000e-04
# linear_solver: Iteration 92 ⛰:-6.7298e+05 Δ⛰:6.4458e+03 ➽:1.0000e-04
# linear_solver: Iteration 93 ⛰:-6.7670e+05 Δ⛰:3.7161e+03 ➽:1.0000e-04
# linear_solver: Iteration 94 ⛰:-6.7679e+05 Δ⛰:8.7305e+01 ➽:1.0000e-04
# linear_solver: Iteration 95 ⛰:-6.7683e+05 Δ⛰:4.4457e+01 ➽:1.0000e-04
# linear_solver: Iteration 96 ⛰:-6.7698e+05 Δ⛰:1.4882e+02 ➽:1.0000e-04
# linear_solver: Iteration 97 ⛰:-6.8505e+05 Δ⛰:8.0725e+03 ➽:1.0000e-04
# linear_solver: Iteration 98 ⛰:-6.8606e+05 Δ⛰:1.0093e+03 ➽:1.0000e-04
# linear_solver: Iteration 99 ⛰:-6.8688e+05 Δ⛰:8.2066e+02 ➽:1.0000e-04
# linear_solver: Iteration ✖✖✖ (100) ⛰:-6.8775e+05 Δ⛰:8.6941e+02 ➽:1.0000e-04
# linear_solver: Iteration 0 ⛰:+2.6556e+08 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:+6.6517e+07 Δ⛰:1.9904e+08 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:+3.0690e+07 Δ⛰:3.5826e+07 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:+1.4247e+07 Δ⛰:1.6443e+07 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:+1.2704e+07 Δ⛰:1.5429e+06 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:+9.7837e+06 Δ⛰:2.9205e+06 ➽:1.0000e-04
# linear_solver: Iteration 6 ⛰:+8.2291e+06 Δ⛰:1.5546e+06 ➽:1.0000e-04
# linear_solver: Iteration 7 ⛰:+7.3290e+06 Δ⛰:9.0009e+05 ➽:1.0000e-04
# linear_solver: Iteration 8 ⛰:+7.2711e+06 Δ⛰:5.7904e+04 ➽:1.0000e-04
# linear_solver: Iteration 9 ⛰:+7.0202e+06 Δ⛰:2.5088e+05 ➽:1.0000e-04
# linear_solver: Iteration 10 ⛰:+5.5130e+06 Δ⛰:1.5072e+06 ➽:1.0000e-04
# linear_solver: Iteration 11 ⛰:+4.1895e+06 Δ⛰:1.3236e+06 ➽:1.0000e-04
# linear_solver: Iteration 12 ⛰:+3.5622e+06 Δ⛰:6.2723e+05 ➽:1.0000e-04
# linear_solver: Iteration 13 ⛰:+2.6723e+06 Δ⛰:8.8992e+05 ➽:1.0000e-04
# linear_solver: Iteration 14 ⛰:+2.6538e+06 Δ⛰:1.8485e+04 ➽:1.0000e-04
# linear_solver: Iteration 15 ⛰:+2.0626e+06 Δ⛰:5.9125e+05 ➽:1.0000e-04
# linear_solver: Iteration 16 ⛰:+1.9022e+06 Δ⛰:1.6037e+05 ➽:1.0000e-04
# linear_solver: Iteration 17 ⛰:+1.4971e+06 Δ⛰:4.0512e+05 ➽:1.0000e-04
# linear_solver: Iteration 18 ⛰:+1.1078e+06 Δ⛰:3.8928e+05 ➽:1.0000e-04
# linear_solver: Iteration 19 ⛰:+8.5367e+05 Δ⛰:2.5416e+05 ➽:1.0000e-04
# linear_solver: Iteration 20 ⛰:+8.2285e+05 Δ⛰:3.0815e+04 ➽:1.0000e-04
# linear_solver: Iteration 21 ⛰:+7.7902e+05 Δ⛰:4.3835e+04 ➽:1.0000e-04
# linear_solver: Iteration 22 ⛰:+5.5850e+05 Δ⛰:2.2052e+05 ➽:1.0000e-04
# linear_solver: Iteration 23 ⛰:+5.4832e+05 Δ⛰:1.0180e+04 ➽:1.0000e-04
# linear_solver: Iteration 24 ⛰:+4.5797e+05 Δ⛰:9.0348e+04 ➽:1.0000e-04
# linear_solver: Iteration 25 ⛰:+3.4601e+05 Δ⛰:1.1196e+05 ➽:1.0000e-04
# linear_solver: Iteration 26 ⛰:+3.3943e+05 Δ⛰:6.5811e+03 ➽:1.0000e-04
# linear_solver: Iteration 27 ⛰:+3.2997e+05 Δ⛰:9.4557e+03 ➽:1.0000e-04
# linear_solver: Iteration 28 ⛰:+3.0241e+05 Δ⛰:2.7567e+04 ➽:1.0000e-04
# linear_solver: Iteration 29 ⛰:+2.0999e+05 Δ⛰:9.2414e+04 ➽:1.0000e-04
# linear_solver: Iteration 30 ⛰:+1.0841e+05 Δ⛰:1.0158e+05 ➽:1.0000e-04
# linear_solver: Iteration 31 ⛰:+2.0069e+04 Δ⛰:8.8344e+04 ➽:1.0000e-04
# linear_solver: Iteration 32 ⛰:+1.7340e+04 Δ⛰:2.7289e+03 ➽:1.0000e-04
# linear_solver: Iteration 33 ⛰:+3.2305e+03 Δ⛰:1.4109e+04 ➽:1.0000e-04
# linear_solver: Iteration 34 ⛰:-4.6401e+04 Δ⛰:4.9631e+04 ➽:1.0000e-04
# linear_solver: Iteration 35 ⛰:-6.0342e+04 Δ⛰:1.3941e+04 ➽:1.0000e-04
# linear_solver: Iteration 36 ⛰:-6.3409e+04 Δ⛰:3.0675e+03 ➽:1.0000e-04
# linear_solver: Iteration 37 ⛰:-1.2632e+05 Δ⛰:6.2913e+04 ➽:1.0000e-04
# linear_solver: Iteration 38 ⛰:-1.2647e+05 Δ⛰:1.4653e+02 ➽:1.0000e-04
# linear_solver: Iteration 39 ⛰:-1.8212e+05 Δ⛰:5.5652e+04 ➽:1.0000e-04
# linear_solver: Iteration 40 ⛰:-1.9121e+05 Δ⛰:9.0889e+03 ➽:1.0000e-04
# linear_solver: Iteration 41 ⛰:-2.2057e+05 Δ⛰:2.9362e+04 ➽:1.0000e-04
# linear_solver: Iteration 42 ⛰:-2.3663e+05 Δ⛰:1.6058e+04 ➽:1.0000e-04
# linear_solver: Iteration 43 ⛰:-2.6134e+05 Δ⛰:2.4713e+04 ➽:1.0000e-04
# linear_solver: Iteration 44 ⛰:-2.6446e+05 Δ⛰:3.1120e+03 ➽:1.0000e-04
# linear_solver: Iteration 72 ⛰:-5.9580e+05 Δ⛰:2.9345e+03 ➽:1.0000e-04
# linear_solver: Iteration 73 ⛰:-6.0374e+05 Δ⛰:7.9429e+03 ➽:1.0000e-04
# linear_solver: Iteration 74 ⛰:-6.0749e+05 Δ⛰:3.7495e+03 ➽:1.0000e-04
# linear_solver: Iteration 75 ⛰:-6.0760e+05 Δ⛰:1.0463e+02 ➽:1.0000e-04
# linear_solver: Iteration 76 ⛰:-6.0786e+05 Δ⛰:2.5960e+02 ➽:1.0000e-04
# linear_solver: Iteration 77 ⛰:-6.1052e+05 Δ⛰:2.6656e+03 ➽:1.0000e-04
# linear_solver: Iteration 78 ⛰:-6.1954e+05 Δ⛰:9.0170e+03 ➽:1.0000e-04
# linear_solver: Iteration 79 ⛰:-6.2016e+05 Δ⛰:6.1602e+02 ➽:1.0000e-04
# linear_solver: Iteration 80 ⛰:-6.2202e+05 Δ⛰:1.8642e+03 ➽:1.0000e-04
# linear_solver: Iteration 81 ⛰:-6.3419e+05 Δ⛰:1.2176e+04 ➽:1.0000e-04
# linear_solver: Iteration 82 ⛰:-6.3581e+05 Δ⛰:1.6174e+03 ➽:1.0000e-04
# linear_solver: Iteration 83 ⛰:-6.3928e+05 Δ⛰:3.4631e+03 ➽:1.0000e-04
# linear_solver: Iteration 84 ⛰:-6.4615e+05 Δ⛰:6.8757e+03 ➽:1.0000e-04
# linear_solver: Iteration 85 ⛰:-6.4655e+05 Δ⛰:3.9650e+02 ➽:1.0000e-04
# linear_solver: Iteration 86 ⛰:-6.4667e+05 Δ⛰:1.1903e+02 ➽:1.0000e-04
# linear_solver: Iteration 87 ⛰:-6.5321e+05 Δ⛰:6.5480e+03 ➽:1.0000e-04
# linear_solver: Iteration 88 ⛰:-6.5324e+05 Δ⛰:2.8238e+01 ➽:1.0000e-04
# linear_solver: Iteration 89 ⛰:-6.6213e+05 Δ⛰:8.8823e+03 ➽:1.0000e-04
# linear_solver: Iteration 90 ⛰:-6.6933e+05 Δ⛰:7.2077e+03 ➽:1.0000e-04
# linear_solver: Iteration 91 ⛰:-6.6974e+05 Δ⛰:4.0593e+02 ➽:1.0000e-04
# linear_solver: Iteration 92 ⛰:-6.7748e+05 Δ⛰:7.7371e+03 ➽:1.0000e-04
# linear_solver: Iteration 93 ⛰:-6.7775e+05 Δ⛰:2.6982e+02 ➽:1.0000e-04
# linear_solver: Iteration 94 ⛰:-6.7781e+05 Δ⛰:6.7197e+01 ➽:1.0000e-04
# linear_solver: Iteration 95 ⛰:-6.7921e+05 Δ⛰:1.3987e+03 ➽:1.0000e-04
# linear_solver: Iteration 96 ⛰:-6.8456e+05 Δ⛰:5.3476e+03 ➽:1.0000e-04
# linear_solver: Iteration 97 ⛰:-6.8687e+05 Δ⛰:2.3116e+03 ➽:1.0000e-04
# linear_solver: Iteration 98 ⛰:-6.8842e+05 Δ⛰:1.5529e+03 ➽:1.0000e-04
# linear_solver: Iteration 99 ⛰:-6.9171e+05 Δ⛰:3.2882e+03 ➽:1.0000e-04
# linear_solver: Iteration ✖✖✖ (100) ⛰:-6.9189e+05 Δ⛰:1.7856e+02 ➽:1.0000e-04
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:1.136833e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+3.160303e+14 Δ⛰:8.263148e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:7.007644e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+8.278550e+13 Δ⛰:2.332448e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:3.882648e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+2.089163e+13 Δ⛰:6.189387e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:2.010410e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+5.166679e+12 Δ⛰:1.572495e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:1.018321e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 5 ⛰:+1.263706e+12 Δ⛰:3.902973e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:1.532190e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+7.702162e+14 Δ⛰:1.899416e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:1.003521e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+2.087363e+14 Δ⛰:5.614799e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:6.338202e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+5.384118e+13 Δ⛰:1.548952e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:3.822535e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+1.345729e+13 Δ⛰:4.038389e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:2.073993e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 5 ⛰:+3.305859e+12 Δ⛰:1.015143e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:36 |↘|:1.085031e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 6 ⛰:+8.094575e+11 Δ⛰:2.496402e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:4.619613e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+1.537333e+13 Δ⛰:4.141882e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:3.074909e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+4.020319e+12 Δ⛰:1.135301e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:2.146751e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+1.032804e+12 Δ⛰:2.987515e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:1.263845e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+2.662672e+11 Δ⛰:7.665367e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:3.312706e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+1.953591e+12 Δ⛰:4.937308e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:1.736978e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+5.285737e+11 Δ⛰:1.425017e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:8.924728e+01 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+1.422929e+11 Δ⛰:3.862809e+11
# kl_minimizer: →:0.03125 ↺:False #∇²:24 |↘|:8.793598e+01 🞋:1.643660e+02
# kl_minimizer: Iteration 1 ⛰:+1.501168e+07 Δ⛰:4.158512e+06 🞋:1.000000e-04
# OPTIMIZE_KL: Iteration 0002 ⛰:+1.5012e+07
# OPTIMIZE_KL: #(Nonlinear sampling steps) (5, 6, 4, 3)
# OPTIMIZE_KL: #(KL minimization steps) 1
# OPTIMIZE_KL: Likelihood residual(s):
# 'reduced χ²: 1.5e+02± 1.1e+02, avg:     -2.6±    0.92, #dof: 162412'
#
# OPTIMIZE_KL: Prior residual(s):
# background_std          :: 'reduced χ²: 8.9e+01±    0.44, avg:     +5.3±    0.44, #dof:      4'
# flexibility             :: 'reduced χ²:     2.6±    0.61, avg:    -0.51±    0.43, #dof:      4'
# fluctuations            :: 'reduced χ²:     4.0±     1.2, avg:     -1.2±    0.24, #dof:      4'
# loglogavgslope          :: 'reduced χ²:     2.5±    0.81, avg:    +0.14±    0.36, #dof:      4'
# mixing_offset           :: 'reduced χ²:     1.6±    0.87, avg:    -0.21±    0.27, #dof:      4'
# mixture_matrix          :: 'reduced χ²:     3.0±    0.68, avg:     +0.8±   0.053, #dof:     16'
# poisson_scale           :: 'reduced χ²: 1.2e+02±    0.72, avg:     +6.2±    0.33, #dof:      4'
# psf_rotation            :: 'reduced χ²:     2.3±     1.5, avg:     -0.3±    0.31, #dof:      4'
# psf_sigma               :: 'reduced χ²:     1.6±    0.61, avg:    +0.22±    0.16, #dof:      4'
# spectrum                :: 'reduced χ²:     2.0±  0.0018, avg: -0.00023±  0.0011, #dof: 550648'
# xi                      :: 'reduced χ²:     2.0±  0.0024, avg:  +0.0018± 0.00067, #dof:1092960'
# zeromode                :: 'reduced χ²:     2.0±     1.2, avg:   -0.048±   0.056, #dof:      4'
#
#
# OPTIMIZE_KL: Starting 0003
# linear_solver: Iteration 0 ⛰:+2.5333e+08 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:+2.4678e+07 Δ⛰:2.2866e+08 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:+9.5209e+06 Δ⛰:1.5157e+07 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:+6.1725e+06 Δ⛰:3.3484e+06 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:+4.1324e+06 Δ⛰:2.0401e+06 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:+3.1450e+06 Δ⛰:9.8736e+05 ➽:1.0000e-04
# linear_solver: Iteration 6 ⛰:+2.8064e+06 Δ⛰:3.3857e+05 ➽:1.0000e-04
# linear_solver: Iteration 7 ⛰:+2.0150e+06 Δ⛰:7.9147e+05 ➽:1.0000e-04
# linear_solver: Iteration 8 ⛰:+1.8727e+06 Δ⛰:1.4225e+05 ➽:1.0000e-04
# linear_solver: Iteration 9 ⛰:+1.7197e+06 Δ⛰:1.5301e+05 ➽:1.0000e-04
# linear_solver: Iteration 10 ⛰:+1.1155e+06 Δ⛰:6.0423e+05 ➽:1.0000e-04
# linear_solver: Iteration 11 ⛰:+9.2096e+05 Δ⛰:1.9452e+05 ➽:1.0000e-04
# linear_solver: Iteration 12 ⛰:+6.3795e+05 Δ⛰:2.8301e+05 ➽:1.0000e-04
# linear_solver: Iteration 13 ⛰:+3.0642e+05 Δ⛰:3.3153e+05 ➽:1.0000e-04
# linear_solver: Iteration 14 ⛰:+2.7906e+05 Δ⛰:2.7358e+04 ➽:1.0000e-04
# linear_solver: Iteration 15 ⛰:+7.5212e+04 Δ⛰:2.0385e+05 ➽:1.0000e-04
# linear_solver: Iteration 16 ⛰:+6.5432e+04 Δ⛰:9.7793e+03 ➽:1.0000e-04
# linear_solver: Iteration 17 ⛰:-1.2603e+05 Δ⛰:1.9146e+05 ➽:1.0000e-04
# linear_solver: Iteration 18 ⛰:-2.4790e+05 Δ⛰:1.2188e+05 ➽:1.0000e-04
# linear_solver: Iteration 19 ⛰:-2.5346e+05 Δ⛰:5.5630e+03 ➽:1.0000e-04
# linear_solver: Iteration 20 ⛰:-3.3380e+05 Δ⛰:8.0337e+04 ➽:1.0000e-04
# linear_solver: Iteration 21 ⛰:-3.4280e+05 Δ⛰:8.9967e+03 ➽:1.0000e-04
# linear_solver: Iteration 22 ⛰:-3.6746e+05 Δ⛰:2.4660e+04 ➽:1.0000e-04
# linear_solver: Iteration 23 ⛰:-4.2297e+05 Δ⛰:5.5515e+04 ➽:1.0000e-04
# linear_solver: Iteration 24 ⛰:-4.4852e+05 Δ⛰:2.5547e+04 ➽:1.0000e-04
# linear_solver: Iteration 25 ⛰:-4.7279e+05 Δ⛰:2.4269e+04 ➽:1.0000e-04
# linear_solver: Iteration 26 ⛰:-4.8011e+05 Δ⛰:7.3205e+03 ➽:1.0000e-04
# linear_solver: Iteration 27 ⛰:-5.1119e+05 Δ⛰:3.1078e+04 ➽:1.0000e-04
# linear_solver: Iteration 28 ⛰:-5.1537e+05 Δ⛰:4.1801e+03 ➽:1.0000e-04
# linear_solver: Iteration 29 ⛰:-5.2086e+05 Δ⛰:5.4888e+03 ➽:1.0000e-04
# linear_solver: Iteration 30 ⛰:-5.5172e+05 Δ⛰:3.0866e+04 ➽:1.0000e-04
# linear_solver: Iteration 31 ⛰:-5.8127e+05 Δ⛰:2.9549e+04 ➽:1.0000e-04
# linear_solver: Iteration 32 ⛰:-5.8862e+05 Δ⛰:7.3483e+03 ➽:1.0000e-04
# linear_solver: Iteration 33 ⛰:-5.9820e+05 Δ⛰:9.5797e+03 ➽:1.0000e-04
# linear_solver: Iteration 34 ⛰:-5.9910e+05 Δ⛰:8.9829e+02 ➽:1.0000e-04
# linear_solver: Iteration 35 ⛰:-6.0615e+05 Δ⛰:7.0525e+03 ➽:1.0000e-04
# linear_solver: Iteration 36 ⛰:-6.2893e+05 Δ⛰:2.2776e+04 ➽:1.0000e-04
# linear_solver: Iteration 37 ⛰:-6.3942e+05 Δ⛰:1.0496e+04 ➽:1.0000e-04
# linear_solver: Iteration 38 ⛰:-6.4554e+05 Δ⛰:6.1156e+03 ➽:1.0000e-04
# linear_solver: Iteration 39 ⛰:-6.4804e+05 Δ⛰:2.5016e+03 ➽:1.0000e-04
# linear_solver: Iteration 40 ⛰:-6.4816e+05 Δ⛰:1.2008e+02 ➽:1.0000e-04
# linear_solver: Iteration 41 ⛰:-6.4896e+05 Δ⛰:8.0080e+02 ➽:1.0000e-04
# linear_solver: Iteration 42 ⛰:-6.6341e+05 Δ⛰:1.4456e+04 ➽:1.0000e-04
# linear_solver: Iteration 43 ⛰:-6.7408e+05 Δ⛰:1.0665e+04 ➽:1.0000e-04
# linear_solver: Iteration 44 ⛰:-6.7748e+05 Δ⛰:3.4046e+03 ➽:1.0000e-04
# linear_solver: Iteration 45 ⛰:-6.8254e+05 Δ⛰:5.0557e+03 ➽:1.0000e-04
# linear_solver: Iteration 46 ⛰:-6.8732e+05 Δ⛰:4.7834e+03 ➽:1.0000e-04
# linear_solver: Iteration 47 ⛰:-6.9070e+05 Δ⛰:3.3762e+03 ➽:1.0000e-04
# linear_solver: Iteration 48 ⛰:-6.9638e+05 Δ⛰:5.6812e+03 ➽:1.0000e-04
# linear_solver: Iteration 49 ⛰:-6.9684e+05 Δ⛰:4.6065e+02 ➽:1.0000e-04
# linear_solver: Iteration 50 ⛰:-7.1053e+05 Δ⛰:1.3691e+04 ➽:1.0000e-04
# linear_solver: Iteration 51 ⛰:-7.1706e+05 Δ⛰:6.5262e+03 ➽:1.0000e-04
# linear_solver: Iteration 52 ⛰:-7.1747e+05 Δ⛰:4.0886e+02 ➽:1.0000e-04
# linear_solver: Iteration 53 ⛰:-7.1793e+05 Δ⛰:4.6185e+02 ➽:1.0000e-04
# linear_solver: Iteration 54 ⛰:-7.2871e+05 Δ⛰:1.0783e+04 ➽:1.0000e-04
# linear_solver: Iteration 55 ⛰:-7.2908e+05 Δ⛰:3.6576e+02 ➽:1.0000e-04
# linear_solver: Iteration 56 ⛰:-7.3521e+05 Δ⛰:6.1294e+03 ➽:1.0000e-04
# linear_solver: Iteration 57 ⛰:-7.4195e+05 Δ⛰:6.7420e+03 ➽:1.0000e-04
# linear_solver: Iteration 58 ⛰:-7.4235e+05 Δ⛰:4.0480e+02 ➽:1.0000e-04
# linear_solver: Iteration 59 ⛰:-7.4339e+05 Δ⛰:1.0358e+03 ➽:1.0000e-04
# linear_solver: Iteration 60 ⛰:-7.4447e+05 Δ⛰:1.0786e+03 ➽:1.0000e-04
# linear_solver: Iteration 61 ⛰:-7.4630e+05 Δ⛰:1.8354e+03 ➽:1.0000e-04
# linear_solver: Iteration 62 ⛰:-7.4731e+05 Δ⛰:1.0093e+03 ➽:1.0000e-04
# linear_solver: Iteration 63 ⛰:-7.5036e+05 Δ⛰:3.0507e+03 ➽:1.0000e-04
# linear_solver: Iteration 64 ⛰:-7.5137e+05 Δ⛰:1.0016e+03 ➽:1.0000e-04
# linear_solver: Iteration 65 ⛰:-7.5140e+05 Δ⛰:2.9722e+01 ➽:1.0000e-04
# linear_solver: Iteration 66 ⛰:-7.5174e+05 Δ⛰:3.4941e+02 ➽:1.0000e-04
# linear_solver: Iteration 67 ⛰:-7.5800e+05 Δ⛰:6.2565e+03 ➽:1.0000e-04
# linear_solver: Iteration 96 ⛰:-7.8910e+05 Δ⛰:6.9649e+02 ➽:1.0000e-04
# linear_solver: Iteration 97 ⛰:-7.8922e+05 Δ⛰:1.1421e+02 ➽:1.0000e-04
# linear_solver: Iteration 98 ⛰:-7.9080e+05 Δ⛰:1.5873e+03 ➽:1.0000e-04
# linear_solver: Iteration 99 ⛰:-7.9097e+05 Δ⛰:1.6861e+02 ➽:1.0000e-04
# linear_solver: Iteration ✖✖✖ (100) ⛰:-7.9164e+05 Δ⛰:6.6777e+02 ➽:1.0000e-04
# linear_solver: Iteration 0 ⛰:+3.9795e+07 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:+3.2858e+07 Δ⛰:6.9372e+06 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:+6.3309e+06 Δ⛰:2.6527e+07 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:+5.2822e+06 Δ⛰:1.0487e+06 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:+4.4745e+06 Δ⛰:8.0773e+05 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:+2.7843e+06 Δ⛰:1.6901e+06 ➽:1.0000e-04
# linear_solver: Iteration 6 ⛰:+2.5410e+06 Δ⛰:2.4330e+05 ➽:1.0000e-04
# linear_solver: Iteration 7 ⛰:+1.9246e+06 Δ⛰:6.1638e+05 ➽:1.0000e-04
# linear_solver: Iteration 8 ⛰:+1.5291e+06 Δ⛰:3.9553e+05 ➽:1.0000e-04
# linear_solver: Iteration 9 ⛰:+1.5122e+06 Δ⛰:1.6873e+04 ➽:1.0000e-04
# linear_solver: Iteration 10 ⛰:+1.1000e+06 Δ⛰:4.1222e+05 ➽:1.0000e-04
# linear_solver: Iteration 11 ⛰:+6.9208e+05 Δ⛰:4.0792e+05 ➽:1.0000e-04
# linear_solver: Iteration 12 ⛰:+5.2857e+05 Δ⛰:1.6351e+05 ➽:1.0000e-04
# linear_solver: Iteration 13 ⛰:+2.4272e+05 Δ⛰:2.8585e+05 ➽:1.0000e-04
# linear_solver: Iteration 14 ⛰:+9.4488e+04 Δ⛰:1.4824e+05 ➽:1.0000e-04
# linear_solver: Iteration 15 ⛰:+2.0802e+04 Δ⛰:7.3685e+04 ➽:1.0000e-04
# linear_solver: Iteration 16 ⛰:-2.8833e+04 Δ⛰:4.9636e+04 ➽:1.0000e-04
# linear_solver: Iteration 17 ⛰:-1.5220e+05 Δ⛰:1.2336e+05 ➽:1.0000e-04
# linear_solver: Iteration 18 ⛰:-2.5621e+05 Δ⛰:1.0402e+05 ➽:1.0000e-04
# linear_solver: Iteration 19 ⛰:-2.9094e+05 Δ⛰:3.4727e+04 ➽:1.0000e-04
# linear_solver: Iteration 20 ⛰:-3.6746e+05 Δ⛰:7.6517e+04 ➽:1.0000e-04
# linear_solver: Iteration 21 ⛰:-3.6917e+05 Δ⛰:1.7076e+03 ➽:1.0000e-04
# linear_solver: Iteration 22 ⛰:-3.8393e+05 Δ⛰:1.4760e+04 ➽:1.0000e-04
# linear_solver: Iteration 23 ⛰:-4.2642e+05 Δ⛰:4.2499e+04 ➽:1.0000e-04
# linear_solver: Iteration 24 ⛰:-4.6059e+05 Δ⛰:3.4170e+04 ➽:1.0000e-04
# linear_solver: Iteration 25 ⛰:-4.7664e+05 Δ⛰:1.6046e+04 ➽:1.0000e-04
# linear_solver: Iteration 26 ⛰:-4.8994e+05 Δ⛰:1.3299e+04 ➽:1.0000e-04
# linear_solver: Iteration 27 ⛰:-4.9145e+05 Δ⛰:1.5131e+03 ➽:1.0000e-04
# linear_solver: Iteration 28 ⛰:-5.3534e+05 Δ⛰:4.3887e+04 ➽:1.0000e-04
# linear_solver: Iteration 29 ⛰:-5.3638e+05 Δ⛰:1.0387e+03 ➽:1.0000e-04
# linear_solver: Iteration 30 ⛰:-5.6362e+05 Δ⛰:2.7244e+04 ➽:1.0000e-04
# linear_solver: Iteration 31 ⛰:-5.8693e+05 Δ⛰:2.3310e+04 ➽:1.0000e-04
# linear_solver: Iteration 32 ⛰:-6.0230e+05 Δ⛰:1.5364e+04 ➽:1.0000e-04
# linear_solver: Iteration 33 ⛰:-6.1312e+05 Δ⛰:1.0820e+04 ➽:1.0000e-04
# linear_solver: Iteration 34 ⛰:-6.1880e+05 Δ⛰:5.6859e+03 ➽:1.0000e-04
# linear_solver: Iteration 35 ⛰:-6.3162e+05 Δ⛰:1.2815e+04 ➽:1.0000e-04
# linear_solver: Iteration 36 ⛰:-6.3581e+05 Δ⛰:4.1950e+03 ➽:1.0000e-04
# linear_solver: Iteration 37 ⛰:-6.3870e+05 Δ⛰:2.8834e+03 ➽:1.0000e-04
# linear_solver: Iteration 38 ⛰:-6.5567e+05 Δ⛰:1.6969e+04 ➽:1.0000e-04
# linear_solver: Iteration 39 ⛰:-6.5592e+05 Δ⛰:2.5748e+02 ➽:1.0000e-04
# linear_solver: Iteration 40 ⛰:-6.5955e+05 Δ⛰:3.6218e+03 ➽:1.0000e-04
# linear_solver: Iteration 41 ⛰:-6.6047e+05 Δ⛰:9.2929e+02 ➽:1.0000e-04
# linear_solver: Iteration 42 ⛰:-6.7677e+05 Δ⛰:1.6290e+04 ➽:1.0000e-04
# linear_solver: Iteration 43 ⛰:-6.8334e+05 Δ⛰:6.5704e+03 ➽:1.0000e-04
# linear_solver: Iteration 44 ⛰:-6.8923e+05 Δ⛰:5.8947e+03 ➽:1.0000e-04
# linear_solver: Iteration 45 ⛰:-6.8931e+05 Δ⛰:8.2989e+01 ➽:1.0000e-04
# linear_solver: Iteration 46 ⛰:-6.9197e+05 Δ⛰:2.6572e+03 ➽:1.0000e-04
# linear_solver: Iteration 47 ⛰:-6.9474e+05 Δ⛰:2.7717e+03 ➽:1.0000e-04
# linear_solver: Iteration 48 ⛰:-7.0140e+05 Δ⛰:6.6622e+03 ➽:1.0000e-04
# linear_solver: Iteration 49 ⛰:-7.1419e+05 Δ⛰:1.2781e+04 ➽:1.0000e-04
# linear_solver: Iteration 87 ⛰:-7.8191e+05 Δ⛰:4.5286e+02 ➽:1.0000e-04
# linear_solver: Iteration 88 ⛰:-7.8213e+05 Δ⛰:2.1271e+02 ➽:1.0000e-04
# linear_solver: Iteration 89 ⛰:-7.8404e+05 Δ⛰:1.9117e+03 ➽:1.0000e-04
# linear_solver: Iteration 90 ⛰:-7.8506e+05 Δ⛰:1.0217e+03 ➽:1.0000e-04
# linear_solver: Iteration 91 ⛰:-7.8520e+05 Δ⛰:1.3923e+02 ➽:1.0000e-04
# linear_solver: Iteration 92 ⛰:-7.8575e+05 Δ⛰:5.5283e+02 ➽:1.0000e-04
# linear_solver: Iteration 93 ⛰:-7.8724e+05 Δ⛰:1.4860e+03 ➽:1.0000e-04
# linear_solver: Iteration 94 ⛰:-7.8886e+05 Δ⛰:1.6183e+03 ➽:1.0000e-04
# linear_solver: Iteration 95 ⛰:-7.8892e+05 Δ⛰:6.8409e+01 ➽:1.0000e-04
# linear_solver: Iteration 96 ⛰:-7.8914e+05 Δ⛰:2.1169e+02 ➽:1.0000e-04
# linear_solver: Iteration 97 ⛰:-7.8916e+05 Δ⛰:2.6461e+01 ➽:1.0000e-04
# linear_solver: Iteration 98 ⛰:-7.8947e+05 Δ⛰:3.0402e+02 ➽:1.0000e-04
# linear_solver: Iteration 99 ⛰:-7.9053e+05 Δ⛰:1.0663e+03 ➽:1.0000e-04
# linear_solver: Iteration ✖✖✖ (100) ⛰:-7.9094e+05 Δ⛰:4.0862e+02 ➽:1.0000e-04
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:3.946464e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+8.703303e+12 Δ⛰:2.315189e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:2.500705e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+2.285648e+12 Δ⛰:6.417654e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:1.838707e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+5.880343e+11 Δ⛰:1.697614e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:1.998276e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+1.570350e+11 Δ⛰:4.309993e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:8.983275e+01 🞋:1.643660e+02
# nonlinear_solver: Iteration 5 ⛰:+4.440020e+10 Δ⛰:1.126348e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:3.974330e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+4.127112e+12 Δ⛰:1.097744e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:2.340759e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+1.096548e+12 Δ⛰:3.030564e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:1.286110e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+2.890261e+11 Δ⛰:8.075223e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:5.081253e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+3.635462e+12 Δ⛰:8.029841e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:2.831719e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+1.037997e+12 Δ⛰:2.597465e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:1.689175e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+2.870336e+11 Δ⛰:7.509633e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:2.001992e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+8.500095e+10 Δ⛰:2.020326e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:1.503118e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 5 ⛰:+2.735709e+10 Δ⛰:5.764386e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:9.344407e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+2.794715e+12 Δ⛰:1.325841e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:3.860701e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+6.176319e+11 Δ⛰:2.177083e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:1.964775e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+1.525552e+11 Δ⛰:4.650767e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:1.335193e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+4.382265e+10 Δ⛰:1.087326e+11
# kl_minimizer: →:0.25 ↺:False #∇²:25 |↘|:1.019997e+03 🞋:1.643660e+02
# kl_minimizer: Iteration 1 ⛰:+5.053834e+06 Δ⛰:2.787064e+06 🞋:1.000000e-04
# kl_minimizer: WARNING: Energy would increase; aborting
# OPTIMIZE_KL: Iteration 0003 ⛰:+5.0538e+06
# OPTIMIZE_KL: #(Nonlinear sampling steps) (5, 3, 5, 4)
# OPTIMIZE_KL: #(KL minimization steps) 2
# OPTIMIZE_KL: Likelihood residual(s):
# 'reduced χ²:     2.1±     2.4, avg:   -0.046±    0.13, #dof: 162412'
#
# OPTIMIZE_KL: Prior residual(s):
# background_std          :: 'reduced χ²: 8.7e+01±    0.67, avg:     +4.4±    0.49, #dof:      4'
# flexibility             :: 'reduced χ²:     2.9±     2.0, avg:    -0.51±    0.46, #dof:      4'
# fluctuations            :: 'reduced χ²:     5.0±    0.56, avg:     -1.3±    0.72, #dof:      4'
# loglogavgslope          :: 'reduced χ²:     2.7±    0.48, avg:    +0.15±    0.55, #dof:      4'
# mixing_offset           :: 'reduced χ²:     1.3±    0.65, avg:    -0.27±    0.75, #dof:      4'
# mixture_matrix          :: 'reduced χ²:     3.3±     0.7, avg:    +0.91±    0.33, #dof:     16'
# poisson_scale           :: 'reduced χ²:   5e+04± 2.9e+01, avg: +1.3e+02±    0.13, #dof:      4'
# psf_rotation            :: 'reduced χ²:     2.2±    0.56, avg:    -0.29±     0.5, #dof:      4'
# psf_sigma               :: 'reduced χ²:     1.8±    0.65, avg:    +0.21±    0.24, #dof:      4'
# spectrum                :: 'reduced χ²:     2.0±   0.003, avg: -0.00018±  0.0016, #dof: 550648'
# xi                      :: 'reduced χ²:     2.0±  0.0017, avg:  +0.0018±  0.0015, #dof:1092960'
# zeromode                :: 'reduced χ²:     1.1±    0.43, avg:    +0.27±     0.5, #dof:      4'
#
#
# OPTIMIZE_KL: Starting 0004
# linear_solver: Iteration 0 ⛰:-4.2941e+04 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:-3.4159e+05 Δ⛰:2.9865e+05 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:-7.0624e+05 Δ⛰:3.6465e+05 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:-7.5208e+05 Δ⛰:4.5838e+04 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:-8.2668e+05 Δ⛰:7.4603e+04 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:-7.7858e+05 Δ⛰:-4.8097e+04 ➽:1.0000e-04
# linear_solver: Iteration 0 ⛰:+6.0919e+05 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:-4.0430e+05 Δ⛰:1.0135e+06 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:-8.6281e+05 Δ⛰:4.5851e+05 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:-9.4614e+05 Δ⛰:8.3331e+04 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:-9.8258e+05 Δ⛰:3.6439e+04 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:-8.1294e+05 Δ⛰:-1.6964e+05 ➽:1.0000e-04
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:6.014451e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+3.783688e+11 Δ⛰:6.535449e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:11 |↘|:7.294985e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+3.566538e+10 Δ⛰:3.427034e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:17 |↘|:3.053471e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+2.108407e+09 Δ⛰:3.355698e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:23 |↘|:6.625777e+01 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+5.503453e+08 Δ⛰:1.558061e+09
# nonlinear_solver: WARNING: Energy would increase; aborting line search.
# nonlinear_solver: →:0.0 ↺:True #∇²:04 |↘|:0.000000e+00 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+1.320046e+10 Δ⛰:0.000000e+00
# nonlinear_solver: →:1.0 ↺:False #∇²:05 |↘|:4.349883e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+6.773665e+11 Δ⛰:1.400277e+12
# nonlinear_solver: →:1.0 ↺:False #∇²:10 |↘|:4.177103e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+1.904217e+11 Δ⛰:4.869448e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:13 |↘|:1.703089e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+7.055678e+10 Δ⛰:1.198649e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:19 |↘|:5.826634e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+1.389519e+10 Δ⛰:5.666159e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:25 |↘|:1.286470e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 5 ⛰:+2.922364e+09 Δ⛰:1.097283e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:5.189264e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+1.576922e+10 Δ⛰:1.333716e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:2.271660e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+1.902160e+09 Δ⛰:1.386706e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:1.321228e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+6.379449e+08 Δ⛰:1.264215e+09
# kl_minimizer: WARNING: Energy would increase; aborting
# OPTIMIZE_KL: Iteration 0004 ⛰:+1.2683e+07
# OPTIMIZE_KL: #(Nonlinear sampling steps) (4, 1, 5, 3)
# OPTIMIZE_KL: #(KL minimization steps) 1
# OPTIMIZE_KL: Likelihood residual(s):
# 'reduced χ²:    0.45±    0.24, avg:   -0.083±   0.013, #dof: 162412'
#
# OPTIMIZE_KL: Prior residual(s):
# background_std          :: 'reduced χ²: 8.7e+01±    0.49, avg:     +4.4±    0.39, #dof:      4'
# flexibility             :: 'reduced χ²:     3.6±     2.4, avg:    -0.51±     0.3, #dof:      4'
# fluctuations            :: 'reduced χ²:     5.0±    0.91, avg:     -1.5±    0.65, #dof:      4'
# loglogavgslope          :: 'reduced χ²:     5.0±     2.3, avg:    +0.24±    0.37, #dof:      4'
# mixing_offset           :: 'reduced χ²:    0.66±    0.33, avg:    -0.23±    0.25, #dof:      4'
# mixture_matrix          :: 'reduced χ²:     3.7±     1.0, avg:    +0.82±    0.14, #dof:     16'
# poisson_scale           :: 'reduced χ²:   5e+04± 2.6e+02, avg: +1.3e+02±    0.41, #dof:      4'
# psf_rotation            :: 'reduced χ²:     2.4±     1.4, avg:    -0.29±    0.19, #dof:      4'
# psf_sigma               :: 'reduced χ²:     3.2±     3.0, avg:    +0.21±    0.14, #dof:      4'
# spectrum                :: 'reduced χ²:     2.0±  0.0035, avg: -0.00017±  0.0012, #dof: 550648'
# xi                      :: 'reduced χ²:     2.0± 0.00094, avg:  +0.0018± 0.00085, #dof:1092960'
# zeromode                :: 'reduced χ²:    0.69±    0.61, avg:    +0.25±   0.067, #dof:      4'
#
#
# OPTIMIZE_KL: Starting 0005
# linear_solver: Iteration 0 ⛰:+2.8200e+06 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:-1.7870e+05 Δ⛰:2.9987e+06 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:-7.1182e+05 Δ⛰:5.3312e+05 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:-7.0555e+05 Δ⛰:-6.2768e+03 ➽:1.0000e-04
# linear_solver: Iteration 0 ⛰:-2.2242e+05 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:-5.8095e+05 Δ⛰:3.5854e+05 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:-9.6936e+05 Δ⛰:3.8841e+05 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:-9.6936e+05 Δ⛰:0.0000e+00 ➽:1.0000e-04
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:3.294270e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+4.653415e+09 Δ⛰:3.945959e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:1.710154e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+5.123992e+08 Δ⛰:4.141015e+09
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:3.710207e+01 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+3.230506e+08 Δ⛰:1.893485e+08
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:7.638432e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+2.561667e+10 Δ⛰:2.163482e+11
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:1.386438e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+4.499001e+09 Δ⛰:2.111767e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:4.483919e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+7.278769e+09 Δ⛰:5.796297e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:1.723151e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+6.907639e+08 Δ⛰:6.588006e+09
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:7.237515e+01 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+9.071000e+07 Δ⛰:6.000539e+08
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:4.705765e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+2.859412e+10 Δ⛰:2.773484e+11
# nonlinear_solver: →:0.0625 ↺:False #∇²:09 |↘|:1.086255e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+2.648746e+10 Δ⛰:2.106659e+09
# nonlinear_solver: →:1.0 ↺:False #∇²:15 |↘|:3.284885e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+8.765952e+09 Δ⛰:1.772151e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:21 |↘|:3.806957e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+5.481097e+09 Δ⛰:3.284855e+09
# nonlinear_solver: →:1.0 ↺:False #∇²:27 |↘|:1.850497e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 5 ⛰:+1.193783e+09 Δ⛰:4.287315e+09
# nonlinear_solver: →:1.0 ↺:False #∇²:33 |↘|:6.416526e+01 🞋:1.643660e+02
# nonlinear_solver: Iteration 6 ⛰:+2.599411e+08 Δ⛰:9.338417e+08
# CG: WARNING: energy increased
# kl_minimizer: →:1.0 ↺:False #∇²:03 |↘|:4.076781e+02 🞋:1.643660e+02
# kl_minimizer: Iteration 1 ⛰:+4.745193e+06 Δ⛰:6.364294e+04 🞋:1.000000e-04
# kl_minimizer: →:0.5 ↺:False #∇²:15 |↘|:3.631013e+03 🞋:1.643660e+02
# kl_minimizer: Iteration 2 ⛰:+4.631090e+06 Δ⛰:1.141028e+05 🞋:1.000000e-04
# kl_minimizer: →:1.0 ↺:False #∇²:21 |↘|:5.282347e+01 🞋:1.643660e+02
# kl_minimizer: Iteration 3 ⛰:+4.618383e+06 Δ⛰:1.270739e+04 🞋:1.000000e-04
# OPTIMIZE_KL: Iteration 0005 ⛰:+4.6184e+06
# OPTIMIZE_KL: #(Nonlinear sampling steps) (3, 2, 3, 6)
# OPTIMIZE_KL: #(KL minimization steps) 3
# OPTIMIZE_KL: Likelihood residual(s):
# 'reduced χ²:   0.048±   0.028, avg:   +0.038±   0.015, #dof: 162412'
#
# OPTIMIZE_KL: Prior residual(s):
# background_std          :: 'reduced χ²: 8.6e+01±    0.84, avg:     +4.4±   0.088, #dof:      4'
# flexibility             :: 'reduced χ²:     2.0±    0.46, avg:    -0.69±    0.36, #dof:      4'
# fluctuations            :: 'reduced χ²:     6.2±     2.6, avg:     -1.8±    0.36, #dof:      4'
# loglogavgslope          :: 'reduced χ²:     5.0±     1.6, avg:   -0.053±     0.3, #dof:      4'
# mixing_offset           :: 'reduced χ²:    0.86±    0.34, avg:     -0.4±    0.26, #dof:      4'
# mixture_matrix          :: 'reduced χ²:     3.0±     1.1, avg:    +0.91±     0.2, #dof:     16'
# poisson_scale           :: 'reduced χ²: 4.9e+04± 3.4e+02, avg: +1.3e+02±    0.97, #dof:      4'
# psf_rotation            :: 'reduced χ²:     2.4±     0.3, avg:    -0.65±    0.51, #dof:      4'
# psf_sigma               :: 'reduced χ²:     2.2±     1.3, avg:    +0.21±    0.38, #dof:      4'
# spectrum                :: 'reduced χ²:     2.0±  0.0032, avg: -0.00026± 0.00033, #dof: 550648'
# xi                      :: 'reduced χ²:     2.0±  0.0027, avg:  +0.0018± 0.00092, #dof:1092960'
# zeromode                :: 'reduced χ²:     1.2±    0.14, avg:    +0.29±    0.56, #dof:      4'
#
#
# OPTIMIZE_KL: Starting 0006
# linear_solver: Iteration 0 ⛰:-7.1278e+05 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:-1.4694e+06 Δ⛰:7.5666e+05 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:-9.6697e+05 Δ⛰:-5.0247e+05 ➽:1.0000e-04
# linear_solver: Iteration 0 ⛰:-4.9762e+05 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:-6.8863e+05 Δ⛰:1.9101e+05 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:-6.8003e+05 Δ⛰:-8.6007e+03 ➽:1.0000e-04
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:5.104135e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+5.214978e+09 Δ⛰:3.364106e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:2.687345e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+1.547850e+09 Δ⛰:3.667128e+09
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:2.031461e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+8.034011e+08 Δ⛰:7.444489e+08
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:2.642113e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 4 ⛰:+5.273995e+08 Δ⛰:2.760016e+08
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:2.947000e+01 🞋:1.643660e+02
# nonlinear_solver: Iteration 5 ⛰:+4.988090e+08 Δ⛰:2.859049e+07
# nonlinear_solver: WARNING: Energy would increase; aborting line search.
# nonlinear_solver: →:0.0 ↺:True #∇²:211 |↘|:nan 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+6.689497e+11 Δ⛰:0.000000e+00
# nonlinear_solver: →:1.0 ↺:False #∇²:05 |↘|:1.135638e+03 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+1.684352e+11 Δ⛰:1.488587e+11
# nonlinear_solver: →:0.125 ↺:False #∇²:10 |↘|:3.681543e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+1.625712e+11 Δ⛰:5.864009e+09
# nonlinear_solver: WARNING: Energy would increase; aborting line search.
# nonlinear_solver: →:0.0 ↺:True #∇²:221 |↘|:nan 🞋:1.643660e+02
# nonlinear_solver: Iteration 3 ⛰:+1.625712e+11 Δ⛰:0.000000e+00
# nonlinear_solver: →:1.0 ↺:False #∇²:03 |↘|:3.602666e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 1 ⛰:+3.315890e+09 Δ⛰:1.435145e+10
# nonlinear_solver: →:1.0 ↺:False #∇²:09 |↘|:1.490657e+02 🞋:1.643660e+02
# nonlinear_solver: Iteration 2 ⛰:+7.120131e+08 Δ⛰:2.603877e+09

# %% [markdown]
# ### 7. Analyze the Posterior
#
# Channels are in the order returned by `dataset.channel_keys` (all MIRI channels first, then NIRCam).

# %%
import pickle

# Load results
results_dir = Path("tutorial_results_multi")
samples, state = pickle.load(open(results_dir / "last.pkl", "rb"))

# Posterior mean
posterior_means = jft.mean(samples)

# Predicted sky signal (on reference frame)
pred_signal_mean = mixture(posterior_means)

# Predicted data per channel
pred_data_mean = response(posterior_means, pred_signal_mean)

# Plot Predicted Sky Signal
n = dataset.n_channels
fig, axes = plt.subplots(1, n, figsize=(4*n, 4))
for i, key in enumerate(dataset.channel_keys):
    axes[i].imshow(pred_signal_mean[i], origin='lower', norm=LogNorm())
    axes[i].set_title(key, fontsize=8)
plt.suptitle("Predicted Sky Signal (reference frame)")
plt.tight_layout()
plt.show()

# Plot Predicted Data (reprojected + convolved)
fig, axes = plt.subplots(1, n, figsize=(4*n, 4))
for i, key in enumerate(dataset.channel_keys):
    axes[i].imshow(pred_data_mean[i], origin='lower', norm=LogNorm())
    axes[i].set_title(key, fontsize=8)
plt.suptitle("Predicted Data")
plt.tight_layout()
plt.show()

# Plot Observed Data
fig, axes = plt.subplots(1, n, figsize=(4*n, 4))
for i, key in enumerate(dataset.channel_keys):
    data, _, _ = dataset[key]
    axes[i].imshow(data, norm=LogNorm(), origin='lower')
    axes[i].set_title(key, fontsize=8)
plt.suptitle("Observed Data")
plt.tight_layout()
plt.show()

# Plot Residuals (data - predicted, per channel)
fig, axes = plt.subplots(1, n, figsize=(4*n, 4))
for i, key in enumerate(dataset.channel_keys):
    data, _, _ = dataset[key]
    residual = data - pred_data_mean[i]
    axes[i].imshow(residual, origin='lower', cmap='RdBu_r')
    axes[i].set_title(key, fontsize=8)
plt.suptitle("Residuals (data - predicted)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary
#
# In this tutorial, you ran a joint multi-instrument fit with AstroPrism:
#
# | Step | Component | Purpose |
# |------|-----------|---------|
# | 1 | `MultiInstrumentDataset` | Load MIRI + NIRCam into a single dataset |
# | 2 | `MixtureGP` | Shared GP sky model on the MIRI reference frame |
# | 3 | `InstrumentResponse` | Per-channel reprojection + PSF convolution |
# | 4 | `NoiseModel` | Per-channel heteroscedastic noise |
# | 5 | `ForwardModel` | Combine all components |
# | 6 | Joint Likelihood & Inference | Fit all instruments simultaneously |
# | 7 | Analysis | Posterior sky signal and per-instrument residuals |
