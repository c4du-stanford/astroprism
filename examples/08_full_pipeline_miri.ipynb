# %% [markdown]
# # AstroPrism Tutorial: Pipeline Example
#
# This tutorial walks through the complete AstroPrism pipeline for multi-wavelength astronomical image modeling using Gaussian Processes.
#
# **What you'll learn:**
# 1. Loading and organizing multi-channel astronomical data
# 2. Building Gaussian Process priors for the sky model
# 3. Modeling instrument response (reprojection + PSF convolution)
# 4. Constructing the forward model and likelihood
# 5. Running Bayesian inference with VI and NIFTy

# %% [markdown]
# ## Environment
#
# To run this tutorial, create a virtual environment and install AstroPrism in editable mode:
#
# ```bash
# cd /path/to/astroprism
#
# # Create and activate a virtual environment
# python3 -m venv .venv
# source .venv/bin/activate
#
# # Install AstroPrism with dev dependencies
# pip install -e ".[dev]"
#
# # Register the Jupyter kernel
# python -m ipykernel install --user --name=astroprism
# ```
#
# Then select the **astroprism** kernel in Jupyter or VS Code.

# %% [markdown]
# ## Imports

# %%
import sys
import logging
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import warnings
from astropy.utils.exceptions import AstropyWarning

import jax
import jax.numpy as jnp
import jax.random as jr
import nifty8.re as jft

warnings.filterwarnings('ignore', category=AstropyWarning)
logging.getLogger("nifty8.re").setLevel(logging.WARNING)

# %% [markdown]
# ### 1. Data Loading

# %%
# Imports
from astroprism.io import load_dataset, SingleInstrumentDataset

# Load Single Instrument Dataset
path = "../data/tutorial/hack_sample/data_full"
dataset = load_dataset(path=path, instrument="JWST_MIRI", extension="fits")
print(dataset.summary())

# Plot Data
fig, axes = plt.subplots(1, dataset.n_channels, figsize=(4*dataset.n_channels, 4))
for i, key in enumerate(dataset.channel_keys):
    data, wcs, psf = dataset[key]
    axes[i].imshow(data, norm=LogNorm(), origin='lower')
    axes[i].set_title(key)
plt.suptitle("Data")
plt.tight_layout()
plt.show()

# Plot PSF
fig, axes = plt.subplots(1, dataset.n_channels, figsize=(4*dataset.n_channels, 4))

for i, key in enumerate(dataset.channel_keys):
    _, _, psf = dataset[key]
    axes[i].imshow(psf, norm=LogNorm(), origin='lower')
    axes[i].set_title(key)
plt.suptitle("PSF")
plt.tight_layout()
plt.show()
# Out:
# SingleInstrumentDataset Summary:
# --------------------------------
# Number of channels: 4
# Channel keys: ['hlsp_phangs-jwst_jwst_miri_ngc1566_f1000w_v1p0p1_img', 'hlsp_phangs-jwst_jwst_miri_ngc1566_f1130w_v1p0p1_img', 'hlsp_phangs-jwst_jwst_miri_ngc1566_f2100w_v1p0p1_img', 'hlsp_phangs-jwst_jwst_miri_ngc1566_f770w_v1p0p1_img']
# Channel shapes: [(74, 60), (74, 60), (74, 60), (74, 60)]
# Pixel scales: [(0.11091449975820492, 0.1109144997630491), (0.11091449949791077, 0.11091449946799463), (0.11091449907273217, 0.11091449905375952), (0.11091450012231652, 0.11091450010349585)]

# %% [markdown]
# ### 2. Set Up GP Prior

# %%
from astroprism.models.field import FieldModel
from astroprism.models.signal import SignalModel

# FieldModel: independent correlated field per channel
field = FieldModel(
    n_channels=len(dataset),
    shape=dataset.shapes[0],
    distances=dataset.pixel_scales[0],
)

# SignalModel: linear mixing + activation on top of the latent fields
signal = SignalModel(field=field)

print("SignalModel domain keys:", list(signal.domain.keys()))
# Out:
# SignalModel domain keys: ['zeromode', 'fluctuations', 'loglogavgslope', 'spectrum', 'flexibility', 'xi', 'mixing_matrix', 'mixing_offset']

# %% [markdown]
# ### 3. Set Up the Instrument Response Model

# %%
# Imports
from astroprism.models.response import InstrumentResponse

# Instrument Response Model: Reprojects the sky model to the observed frame and convolves with the PSF
response = InstrumentResponse(
    dataset=dataset,
    signal_wcs=dataset.wcs[0],
    signal_shape=dataset.shapes[0],
)

# Print the domain of the InstrumentResponse (parameters)
print("InstrumentResponse domain keys:", list(response.domain.keys()))
# Out:
# InstrumentResponse domain keys: ['psf_smoothing', 'psf_rotation']

# %% [markdown]
# ### 4. Set Up the Noise Model

# %%
# Imports
from astroprism.models.noise import NoiseModel

# NoiseModel: Adds noise to the observed data
noise = NoiseModel(n_channels=len(dataset))

# Print the domain of the NoiseModel (parameters)
print("NoiseModel domain keys:", list(noise.domain.keys()))
# Out:
# NoiseModel domain keys: ['noise_floor', 'noise_scale']

# %% [markdown]
# ### 5. Set Up the Forward Model

# %%
# Imports
from astroprism.models.forward import ForwardModel

# ForwardModel: Combines all models
model = ForwardModel(signal, response, noise)

# Print the domain of the ForwardModel (parameters)
print("ForwardModel domain keys:", list(model.domain.keys()))
# Out:
# ForwardModel domain keys: ['zeromode', 'fluctuations', 'loglogavgslope', 'spectrum', 'flexibility', 'xi', 'mixing_matrix', 'mixing_offset', 'psf_smoothing', 'psf_rotation', 'noise_floor', 'noise_scale']

# %% [markdown]
# ### 6. Set Up the Likelihood and Run Inference

# %%
# Imports
from astroprism.models.likelihood import build_likelihood
from astroprism.inference.vi import run_inference

# Build likelihood: Combines data, model, and mask (readout)
likelihood = build_likelihood(dataset, model, mask=dataset.readout)

# Run inference: Optimizes the likelihood 
samples, state = run_inference(
    likelihood, 
    n_iterations=10,   # number of iterations
    n_samples=2,      # number of samples
    seed=42,
    output_directory="tutorial_results2"
)
# Out:
# OPTIMIZE_KL: Starting 0001
# linear_solver: Iteration 0 ⛰:+5.5596e+08 Δ⛰:inf ➽:1.0000e-03
# linear_solver: Iteration 1 ⛰:+1.9159e+08 Δ⛰:3.6437e+08 ➽:1.0000e-03
# linear_solver: Iteration 2 ⛰:+1.3112e+08 Δ⛰:6.0478e+07 ➽:1.0000e-03
# linear_solver: Iteration 3 ⛰:+6.7582e+07 Δ⛰:6.3533e+07 ➽:1.0000e-03
# linear_solver: Iteration 4 ⛰:+4.1016e+07 Δ⛰:2.6567e+07 ➽:1.0000e-03
# linear_solver: Iteration 5 ⛰:+2.8487e+07 Δ⛰:1.2529e+07 ➽:1.0000e-03
# linear_solver: Iteration 6 ⛰:+1.2643e+07 Δ⛰:1.5843e+07 ➽:1.0000e-03
# linear_solver: Iteration 7 ⛰:+9.1121e+06 Δ⛰:3.5313e+06 ➽:1.0000e-03
# linear_solver: Iteration 8 ⛰:+5.0854e+06 Δ⛰:4.0267e+06 ➽:1.0000e-03
# linear_solver: Iteration 9 ⛰:+3.9513e+06 Δ⛰:1.1341e+06 ➽:1.0000e-03
# linear_solver: Iteration 10 ⛰:+3.0632e+06 Δ⛰:8.8806e+05 ➽:1.0000e-03
# linear_solver: Iteration 11 ⛰:+2.2152e+06 Δ⛰:8.4799e+05 ➽:1.0000e-03
# linear_solver: Iteration 12 ⛰:+1.9811e+06 Δ⛰:2.3411e+05 ➽:1.0000e-03
# linear_solver: Iteration 13 ⛰:+1.8774e+06 Δ⛰:1.0371e+05 ➽:1.0000e-03
# linear_solver: Iteration 14 ⛰:+1.4909e+06 Δ⛰:3.8648e+05 ➽:1.0000e-03
# linear_solver: Iteration 15 ⛰:+1.0715e+06 Δ⛰:4.1940e+05 ➽:1.0000e-03
# linear_solver: Iteration 16 ⛰:+1.0121e+06 Δ⛰:5.9445e+04 ➽:1.0000e-03
# linear_solver: Iteration 17 ⛰:+9.9505e+05 Δ⛰:1.7048e+04 ➽:1.0000e-03
# linear_solver: Iteration 18 ⛰:+5.8020e+05 Δ⛰:4.1485e+05 ➽:1.0000e-03
# linear_solver: Iteration 19 ⛰:+5.1943e+05 Δ⛰:6.0773e+04 ➽:1.0000e-03
# linear_solver: Iteration 20 ⛰:+4.7956e+05 Δ⛰:3.9866e+04 ➽:1.0000e-03
# linear_solver: Iteration 21 ⛰:+3.3741e+05 Δ⛰:1.4215e+05 ➽:1.0000e-03
# linear_solver: Iteration 22 ⛰:+3.3491e+05 Δ⛰:2.5042e+03 ➽:1.0000e-03
# linear_solver: Iteration 23 ⛰:+2.5847e+05 Δ⛰:7.6441e+04 ➽:1.0000e-03
# linear_solver: Iteration 24 ⛰:+2.3476e+05 Δ⛰:2.3711e+04 ➽:1.0000e-03
# linear_solver: Iteration 25 ⛰:+1.8839e+05 Δ⛰:4.6369e+04 ➽:1.0000e-03
# linear_solver: Iteration 26 ⛰:+1.8743e+05 Δ⛰:9.5648e+02 ➽:1.0000e-03
# linear_solver: Iteration 27 ⛰:+1.8581e+05 Δ⛰:1.6197e+03 ➽:1.0000e-03
# linear_solver: Iteration 28 ⛰:+1.5621e+05 Δ⛰:2.9599e+04 ➽:1.0000e-03
# linear_solver: Iteration 29 ⛰:+1.5575e+05 Δ⛰:4.6720e+02 ➽:1.0000e-03
# linear_solver: Iteration 30 ⛰:+1.5357e+05 Δ⛰:2.1780e+03 ➽:1.0000e-03
# linear_solver: Iteration 31 ⛰:+1.5305e+05 Δ⛰:5.1913e+02 ➽:1.0000e-03
# linear_solver: Iteration 32 ⛰:+1.0637e+05 Δ⛰:4.6680e+04 ➽:1.0000e-03
# linear_solver: Iteration 33 ⛰:+1.0290e+05 Δ⛰:3.4694e+03 ➽:1.0000e-03
# linear_solver: Iteration 34 ⛰:+9.7469e+04 Δ⛰:5.4310e+03 ➽:1.0000e-03
# linear_solver: Iteration 35 ⛰:+9.1871e+04 Δ⛰:5.5983e+03 ➽:1.0000e-03
# linear_solver: Iteration 36 ⛰:+7.8873e+04 Δ⛰:1.2997e+04 ➽:1.0000e-03
# linear_solver: Iteration 37 ⛰:+6.4957e+04 Δ⛰:1.3917e+04 ➽:1.0000e-03
# linear_solver: Iteration 38 ⛰:+6.4771e+04 Δ⛰:1.8614e+02 ➽:1.0000e-03
# linear_solver: Iteration 39 ⛰:+6.4732e+04 Δ⛰:3.8464e+01 ➽:1.0000e-03
# linear_solver: Iteration 40 ⛰:+6.4296e+04 Δ⛰:4.3600e+02 ➽:1.0000e-03
# linear_solver: Iteration 41 ⛰:+6.1278e+04 Δ⛰:3.0183e+03 ➽:1.0000e-03
# linear_solver: Iteration 42 ⛰:+5.0558e+04 Δ⛰:1.0720e+04 ➽:1.0000e-03
# linear_solver: Iteration 43 ⛰:+4.2309e+04 Δ⛰:8.2483e+03 ➽:1.0000e-03
# linear_solver: Iteration 44 ⛰:+4.2031e+04 Δ⛰:2.7837e+02 ➽:1.0000e-03
# linear_solver: Iteration 45 ⛰:+4.1268e+04 Δ⛰:7.6324e+02 ➽:1.0000e-03
# linear_solver: Iteration 46 ⛰:+4.1214e+04 Δ⛰:5.3853e+01 ➽:1.0000e-03
# linear_solver: Iteration 47 ⛰:+4.0159e+04 Δ⛰:1.0547e+03 ➽:1.0000e-03
# linear_solver: Iteration 48 ⛰:+3.7068e+04 Δ⛰:3.0916e+03 ➽:1.0000e-03
# linear_solver: Iteration 49 ⛰:+3.0990e+04 Δ⛰:6.0779e+03 ➽:1.0000e-03
# linear_solver: Iteration 50 ⛰:+3.0860e+04 Δ⛰:1.2985e+02 ➽:1.0000e-03
# linear_solver: Iteration 51 ⛰:+3.0719e+04 Δ⛰:1.4114e+02 ➽:1.0000e-03
# linear_solver: Iteration 52 ⛰:+2.2676e+04 Δ⛰:8.0422e+03 ➽:1.0000e-03
# linear_solver: Iteration 53 ⛰:+2.1868e+04 Δ⛰:8.0849e+02 ➽:1.0000e-03
# linear_solver: Iteration 54 ⛰:+2.1291e+04 Δ⛰:5.7741e+02 ➽:1.0000e-03
# linear_solver: Iteration 55 ⛰:+2.1014e+04 Δ⛰:2.7618e+02 ➽:1.0000e-03
# linear_solver: Iteration 56 ⛰:+1.5333e+04 Δ⛰:5.6816e+03 ➽:1.0000e-03
# linear_solver: Iteration 57 ⛰:+1.5154e+04 Δ⛰:1.7904e+02 ➽:1.0000e-03
# linear_solver: Iteration 58 ⛰:+1.4582e+04 Δ⛰:5.7136e+02 ➽:1.0000e-03
# linear_solver: Iteration 59 ⛰:+1.4549e+04 Δ⛰:3.3428e+01 ➽:1.0000e-03
# linear_solver: Iteration 60 ⛰:+6.8131e+03 Δ⛰:7.7359e+03 ➽:1.0000e-03
# linear_solver: Iteration 61 ⛰:+6.7100e+03 Δ⛰:1.0304e+02 ➽:1.0000e-03
# linear_solver: Iteration 62 ⛰:+6.6769e+03 Δ⛰:3.3145e+01 ➽:1.0000e-03
# linear_solver: Iteration 63 ⛰:+6.6558e+03 Δ⛰:2.1081e+01 ➽:1.0000e-03
# linear_solver: Iteration 64 ⛰:+6.6532e+03 Δ⛰:2.6331e+00 ➽:1.0000e-03
# linear_solver: Iteration 65 ⛰:+6.5754e+03 Δ⛰:7.7751e+01 ➽:1.0000e-03
# linear_solver: Iteration 66 ⛰:+5.5880e+03 Δ⛰:9.8738e+02 ➽:1.0000e-03
# linear_solver: Iteration 7 ⛰:+1.1592e+07 Δ⛰:5.1951e+06 ➽:1.0000e-03
# linear_solver: Iteration 8 ⛰:+4.2455e+06 Δ⛰:7.3469e+06 ➽:1.0000e-03
# linear_solver: Iteration 9 ⛰:+2.4208e+06 Δ⛰:1.8247e+06 ➽:1.0000e-03
# linear_solver: Iteration 10 ⛰:+1.5472e+06 Δ⛰:8.7362e+05 ➽:1.0000e-03
# linear_solver: Iteration 11 ⛰:+1.1770e+06 Δ⛰:3.7020e+05 ➽:1.0000e-03
# linear_solver: Iteration 12 ⛰:+1.1627e+06 Δ⛰:1.4263e+04 ➽:1.0000e-03
# linear_solver: Iteration 13 ⛰:+1.0688e+06 Δ⛰:9.3909e+04 ➽:1.0000e-03
# linear_solver: Iteration 14 ⛰:+9.3099e+05 Δ⛰:1.3782e+05 ➽:1.0000e-03
# linear_solver: Iteration 15 ⛰:+7.9871e+05 Δ⛰:1.3228e+05 ➽:1.0000e-03
# linear_solver: Iteration 16 ⛰:+6.8437e+05 Δ⛰:1.1434e+05 ➽:1.0000e-03
# linear_solver: Iteration 17 ⛰:+6.8063e+05 Δ⛰:3.7367e+03 ➽:1.0000e-03
# linear_solver: Iteration 18 ⛰:+4.6435e+05 Δ⛰:2.1628e+05 ➽:1.0000e-03
# linear_solver: Iteration 19 ⛰:+3.9287e+05 Δ⛰:7.1478e+04 ➽:1.0000e-03
# linear_solver: Iteration 20 ⛰:+3.9140e+05 Δ⛰:1.4771e+03 ➽:1.0000e-03
# linear_solver: Iteration 21 ⛰:+3.8997e+05 Δ⛰:1.4264e+03 ➽:1.0000e-03
# linear_solver: Iteration 22 ⛰:+3.2285e+05 Δ⛰:6.7122e+04 ➽:1.0000e-03
# linear_solver: Iteration 23 ⛰:+2.4189e+05 Δ⛰:8.0956e+04 ➽:1.0000e-03
# linear_solver: Iteration 24 ⛰:+2.1467e+05 Δ⛰:2.7221e+04 ➽:1.0000e-03
# linear_solver: Iteration 25 ⛰:+1.8369e+05 Δ⛰:3.0981e+04 ➽:1.0000e-03
# linear_solver: Iteration 26 ⛰:+1.8144e+05 Δ⛰:2.2513e+03 ➽:1.0000e-03
# linear_solver: Iteration 27 ⛰:+1.7711e+05 Δ⛰:4.3288e+03 ➽:1.0000e-03
# linear_solver: Iteration 28 ⛰:+1.5663e+05 Δ⛰:2.0484e+04 ➽:1.0000e-03
# linear_solver: Iteration 29 ⛰:+1.3442e+05 Δ⛰:2.2211e+04 ➽:1.0000e-03
# linear_solver: Iteration 30 ⛰:+1.3286e+05 Δ⛰:1.5514e+03 ➽:1.0000e-03
# linear_solver: Iteration 31 ⛰:+1.3116e+05 Δ⛰:1.7038e+03 ➽:1.0000e-03
# linear_solver: Iteration 32 ⛰:+1.1369e+05 Δ⛰:1.7472e+04 ➽:1.0000e-03
# linear_solver: Iteration 33 ⛰:+1.1260e+05 Δ⛰:1.0838e+03 ➽:1.0000e-03
# linear_solver: Iteration 34 ⛰:+9.7674e+04 Δ⛰:1.4929e+04 ➽:1.0000e-03
# linear_solver: Iteration 35 ⛰:+9.6584e+04 Δ⛰:1.0902e+03 ➽:1.0000e-03
# linear_solver: Iteration 36 ⛰:+9.6501e+04 Δ⛰:8.2950e+01 ➽:1.0000e-03
# linear_solver: Iteration 37 ⛰:+8.1983e+04 Δ⛰:1.4518e+04 ➽:1.0000e-03
# linear_solver: Iteration 38 ⛰:+7.8522e+04 Δ⛰:3.4608e+03 ➽:1.0000e-03
# linear_solver: Iteration 39 ⛰:+7.8495e+04 Δ⛰:2.7156e+01 ➽:1.0000e-03
# linear_solver: Iteration 40 ⛰:+7.1391e+04 Δ⛰:7.1044e+03 ➽:1.0000e-03
# linear_solver: Iteration 41 ⛰:+6.9906e+04 Δ⛰:1.4844e+03 ➽:1.0000e-03
# linear_solver: Iteration 42 ⛰:+6.4354e+04 Δ⛰:5.5521e+03 ➽:1.0000e-03
# linear_solver: Iteration 43 ⛰:+5.5492e+04 Δ⛰:8.8626e+03 ➽:1.0000e-03
# linear_solver: Iteration 44 ⛰:+5.4078e+04 Δ⛰:1.4135e+03 ➽:1.0000e-03
# linear_solver: Iteration 45 ⛰:+4.9011e+04 Δ⛰:5.0674e+03 ➽:1.0000e-03
# linear_solver: Iteration 46 ⛰:+4.8884e+04 Δ⛰:1.2642e+02 ➽:1.0000e-03
# linear_solver: Iteration 47 ⛰:+4.7644e+04 Δ⛰:1.2408e+03 ➽:1.0000e-03
# linear_solver: Iteration 48 ⛰:+4.6947e+04 Δ⛰:6.9632e+02 ➽:1.0000e-03
# linear_solver: Iteration 49 ⛰:+3.6164e+04 Δ⛰:1.0783e+04 ➽:1.0000e-03
# linear_solver: Iteration 50 ⛰:+3.5264e+04 Δ⛰:9.0051e+02 ➽:1.0000e-03
# linear_solver: Iteration 51 ⛰:+3.5198e+04 Δ⛰:6.5712e+01 ➽:1.0000e-03
# linear_solver: Iteration 52 ⛰:+3.2048e+04 Δ⛰:3.1499e+03 ➽:1.0000e-03
# linear_solver: Iteration 53 ⛰:+2.7619e+04 Δ⛰:4.4295e+03 ➽:1.0000e-03
# linear_solver: Iteration 54 ⛰:+2.7536e+04 Δ⛰:8.3137e+01 ➽:1.0000e-03
# linear_solver: Iteration 55 ⛰:+2.6869e+04 Δ⛰:6.6706e+02 ➽:1.0000e-03
# linear_solver: Iteration 56 ⛰:+2.1700e+04 Δ⛰:5.1690e+03 ➽:1.0000e-03
# linear_solver: Iteration 57 ⛰:+2.1639e+04 Δ⛰:6.0186e+01 ➽:1.0000e-03
# linear_solver: Iteration 58 ⛰:+2.1501e+04 Δ⛰:1.3846e+02 ➽:1.0000e-03
# linear_solver: Iteration 59 ⛰:+2.0689e+04 Δ⛰:8.1173e+02 ➽:1.0000e-03
# linear_solver: Iteration 60 ⛰:+2.0643e+04 Δ⛰:4.5864e+01 ➽:1.0000e-03
# linear_solver: Iteration 61 ⛰:+1.8778e+04 Δ⛰:1.8655e+03 ➽:1.0000e-03
# linear_solver: Iteration 62 ⛰:+1.6057e+04 Δ⛰:2.7209e+03 ➽:1.0000e-03
# linear_solver: Iteration 63 ⛰:+1.5932e+04 Δ⛰:1.2542e+02 ➽:1.0000e-03
# linear_solver: Iteration 64 ⛰:+1.5838e+04 Δ⛰:9.4066e+01 ➽:1.0000e-03
# linear_solver: Iteration 65 ⛰:+1.5796e+04 Δ⛰:4.1796e+01 ➽:1.0000e-03
# linear_solver: Iteration 66 ⛰:+1.5588e+04 Δ⛰:2.0772e+02 ➽:1.0000e-03
# linear_solver: Iteration 67 ⛰:+1.5411e+04 Δ⛰:1.7723e+02 ➽:1.0000e-03
# linear_solver: Iteration 68 ⛰:+1.3006e+04 Δ⛰:2.4049e+03 ➽:1.0000e-03
# linear_solver: Iteration 69 ⛰:+1.1585e+04 Δ⛰:1.4209e+03 ➽:1.0000e-03
# linear_solver: Iteration 70 ⛰:+1.1377e+04 Δ⛰:2.0846e+02 ➽:1.0000e-03
# linear_solver: Iteration 71 ⛰:+1.1248e+04 Δ⛰:1.2896e+02 ➽:1.0000e-03
# linear_solver: Iteration 72 ⛰:+1.0697e+04 Δ⛰:5.5051e+02 ➽:1.0000e-03
# linear_solver: Iteration 73 ⛰:+1.0537e+04 Δ⛰:1.5991e+02 ➽:1.0000e-03
# linear_solver: Iteration 74 ⛰:+1.0514e+04 Δ⛰:2.3426e+01 ➽:1.0000e-03
# linear_solver: Iteration 75 ⛰:+8.2267e+03 Δ⛰:2.2870e+03 ➽:1.0000e-03
# linear_solver: Iteration 76 ⛰:+8.2231e+03 Δ⛰:3.5947e+00 ➽:1.0000e-03
# linear_solver: Iteration 77 ⛰:+7.3315e+03 Δ⛰:8.9154e+02 ➽:1.0000e-03
# linear_solver: Iteration 78 ⛰:+5.1740e+03 Δ⛰:2.1576e+03 ➽:1.0000e-03
# linear_solver: Iteration 79 ⛰:+5.0060e+03 Δ⛰:1.6802e+02 ➽:1.0000e-03
# linear_solver: Iteration 80 ⛰:+4.9484e+03 Δ⛰:5.7580e+01 ➽:1.0000e-03
# linear_solver: Iteration 81 ⛰:+4.4996e+03 Δ⛰:4.4874e+02 ➽:1.0000e-03
# linear_solver: Iteration 82 ⛰:+4.1743e+03 Δ⛰:3.2530e+02 ➽:1.0000e-03
# linear_solver: Iteration 83 ⛰:+3.9496e+03 Δ⛰:2.2472e+02 ➽:1.0000e-03
# linear_solver: Iteration 84 ⛰:+3.8726e+03 Δ⛰:7.7041e+01 ➽:1.0000e-03
# linear_solver: Iteration 85 ⛰:+3.5139e+03 Δ⛰:3.5870e+02 ➽:1.0000e-03
# linear_solver: Iteration 86 ⛰:+3.4525e+03 Δ⛰:6.1416e+01 ➽:1.0000e-03
# linear_solver: Iteration 87 ⛰:+2.7900e+03 Δ⛰:6.6246e+02 ➽:1.0000e-03
# linear_solver: Iteration 88 ⛰:+2.4647e+03 Δ⛰:3.2533e+02 ➽:1.0000e-03
# linear_solver: Iteration 89 ⛰:+2.4583e+03 Δ⛰:6.4136e+00 ➽:1.0000e-03
# linear_solver: Iteration 90 ⛰:+2.4466e+03 Δ⛰:1.1685e+01 ➽:1.0000e-03
# linear_solver: Iteration 91 ⛰:+5.2645e+02 Δ⛰:1.9201e+03 ➽:1.0000e-03
+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:624 |↘|:5.848036e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 90 ⛰:+1.108119e+06 Δ⛰:4.505380e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:630 |↘|:5.759698e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 91 ⛰:+1.103613e+06 Δ⛰:4.505310e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:636 |↘|:6.444330e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 92 ⛰:+1.099103e+06 Δ⛰:4.510085e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:642 |↘|:6.244516e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 93 ⛰:+1.094600e+06 Δ⛰:4.503377e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:648 |↘|:4.409020e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 94 ⛰:+1.090099e+06 Δ⛰:4.500639e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:654 |↘|:5.384187e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 95 ⛰:+1.085599e+06 Δ⛰:4.500812e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:660 |↘|:5.094409e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 96 ⛰:+1.081096e+06 Δ⛰:4.502970e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:666 |↘|:5.214730e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 97 ⛰:+1.076597e+06 Δ⛰:4.498068e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:672 |↘|:4.448374e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 98 ⛰:+1.072100e+06 Δ⛰:4.497462e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:678 |↘|:4.586012e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 99 ⛰:+1.067603e+06 Δ⛰:4.497221e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:684 |↘|:7.121580e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 100 ⛰:+1.063095e+06 Δ⛰:4.508295e+03 🞋:1.000000e-02
# kl_minimizer: Iteration Limit Reached
# OPTIMIZE_KL: Iteration 0001 ⛰:+1.0631e+06
# OPTIMIZE_KL: Linear sampling status (0, 0)
# OPTIMIZE_KL: #(KL minimization steps) 100
# OPTIMIZE_KL: Likelihood residual(s):
# 'reduced χ²:     0.5±   0.072, avg:    +0.23±   0.041, #dof:  17733'
#
# OPTIMIZE_KL: Prior residual(s):
# flexibility             :: 'reduced χ²:     1.7±     0.9, avg:   -0.011±    0.42, #dof:      4'
# fluctuations            :: 'reduced χ²:     3.2±     1.1, avg:     -1.3±    0.13, #dof:      4'
# loglogavgslope          :: 'reduced χ²:     7.5±     1.3, avg:     -2.4±    0.21, #dof:      4'
# mixing_matrix           :: 'reduced χ²:     6.0±    0.68, avg:     -1.1±    0.07, #dof:     16'
# mixing_offset           :: 'reduced χ²:     3.2±     2.8, avg:     -1.2±    0.73, #dof:      4'
# noise_floor             :: 'reduced χ²:   1e+03±     3.0, avg: +1.6e+01±    0.33, #dof:      4'
# noise_scale             :: 'reduced χ²: 6.8e+03±     1.4, avg: +6.1e+01±  0.0019, #dof:      4'
# psf_rotation            :: 'reduced χ²:     2.1±    0.52, avg:    -0.28±    0.63, #dof:      4'
# psf_smoothing           :: 'reduced χ²:     1.4±    0.39, avg:    +0.22±    0.21, #dof:      4'
# spectrum                :: 'reduced χ²:     1.9±   0.018, avg:    +0.01±  0.0037, #dof:   9408'
# xi                      :: 'reduced χ²:     1.9±    0.01, avg:  +0.0014±    0.01, #dof:  17760'
# zeromode                :: 'reduced χ²:     2.9±     2.0, avg:    +0.69±    0.71, #dof:      4'
#
#
# OPTIMIZE_KL: Starting 0002
# linear_solver: Iteration 0 ⛰:+7.0170e+05 Δ⛰:inf ➽:1.0000e-03
# linear_solver: Iteration 1 ⛰:+5.4084e+05 Δ⛰:1.6086e+05 ➽:1.0000e-03
# linear_solver: Iteration 2 ⛰:+7.8579e+04 Δ⛰:4.6226e+05 ➽:1.0000e-03
# linear_solver: Iteration 3 ⛰:+5.2714e+04 Δ⛰:2.5864e+04 ➽:1.0000e-03
# linear_solver: Iteration 4 ⛰:+1.6596e+04 Δ⛰:3.6118e+04 ➽:1.0000e-03
# linear_solver: Iteration 5 ⛰:-5.1734e+01 Δ⛰:1.6648e+04 ➽:1.0000e-03
# linear_solver: Iteration 6 ⛰:-1.0324e+04 Δ⛰:1.0272e+04 ➽:1.0000e-03
# linear_solver: Iteration 7 ⛰:-1.0949e+04 Δ⛰:6.2518e+02 ➽:1.0000e-03
# linear_solver: Iteration 8 ⛰:-1.2199e+04 Δ⛰:1.2498e+03 ➽:1.0000e-03
# linear_solver: Iteration 9 ⛰:-1.2228e+04 Δ⛰:2.9461e+01 ➽:1.0000e-03
# linear_solver: Iteration 10 ⛰:-1.3438e+04 Δ⛰:1.2095e+03 ➽:1.0000e-03
# linear_solver: Iteration 11 ⛰:-1.3463e+04 Δ⛰:2.5365e+01 ➽:1.0000e-03
# linear_solver: Iteration 12 ⛰:-1.3512e+04 Δ⛰:4.9305e+01 ➽:1.0000e-03
# linear_solver: Iteration 13 ⛰:-1.3513e+04 Δ⛰:1.0311e+00 ➽:1.0000e-03
# linear_solver: Iteration 14 ⛰:-1.3527e+04 Δ⛰:1.4034e+01 ➽:1.0000e-03
# linear_solver: Iteration 15 ⛰:-1.3527e+04 Δ⛰:1.6471e-01 ➽:1.0000e-03
# linear_solver: Iteration 16 ⛰:-1.3528e+04 Δ⛰:3.5716e-01 ➽:1.0000e-03
# linear_solver: Iteration 17 ⛰:-1.3555e+04 Δ⛰:2.7372e+01 ➽:1.0000e-03
# linear_solver: Iteration 18 ⛰:-1.3557e+04 Δ⛰:2.1289e+00 ➽:1.0000e-03
# linear_solver: Iteration 19 ⛰:-1.3566e+04 Δ⛰:8.6726e+00 ➽:1.0000e-03
# linear_solver: Iteration 20 ⛰:-1.3577e+04 Δ⛰:1.0848e+01 ➽:1.0000e-03
# linear_solver: Iteration 21 ⛰:-1.3577e+04 Δ⛰:1.0675e-02 ➽:1.0000e-03
# linear_solver: Iteration 22 ⛰:-1.3579e+04 Δ⛰:1.6858e+00 ➽:1.0000e-03
# linear_solver: Iteration 23 ⛰:-1.3579e+04 Δ⛰:7.0535e-02 ➽:1.0000e-03
# linear_solver: Iteration 24 ⛰:-1.3579e+04 Δ⛰:9.7293e-02 ➽:1.0000e-03
# linear_solver: Iteration 25 ⛰:-1.3585e+04 Δ⛰:6.7611e+00 ➽:1.0000e-03
# linear_solver: Iteration 26 ⛰:-1.3586e+04 Δ⛰:1.5908e-01 ➽:1.0000e-03
# linear_solver: Iteration 27 ⛰:-1.3586e+04 Δ⛰:1.4942e-02 ➽:1.0000e-03
# linear_solver: Iteration 28 ⛰:-1.3586e+04 Δ⛰:4.0322e-03 ➽:1.0000e-03
# linear_solver: Iteration 29 ⛰:-1.3596e+04 Δ⛰:1.0320e+01 ➽:1.0000e-03
# linear_solver: Iteration 30 ⛰:-1.3596e+04 Δ⛰:1.3680e-02 ➽:1.0000e-03
# linear_solver: Iteration 31 ⛰:-1.3596e+04 Δ⛰:1.5746e-01 ➽:1.0000e-03
# linear_solver: Iteration 32 ⛰:-1.3596e+04 Δ⛰:1.9728e-02 ➽:1.0000e-03
# linear_solver: Iteration 33 ⛰:-1.3599e+04 Δ⛰:2.3545e+00 ➽:1.0000e-03
# linear_solver: Iteration 34 ⛰:-1.3599e+04 Δ⛰:4.5280e-04 ➽:1.0000e-03
# linear_solver: Iteration 0 ⛰:+2.7932e+05 Δ⛰:inf ➽:1.0000e-03
# linear_solver: Iteration 1 ⛰:+5.3740e+04 Δ⛰:2.2558e+05 ➽:1.0000e-03
# linear_solver: Iteration 2 ⛰:+3.1023e+04 Δ⛰:2.2717e+04 ➽:1.0000e-03
# linear_solver: Iteration 3 ⛰:+1.6262e+04 Δ⛰:1.4761e+04 ➽:1.0000e-03
# linear_solver: Iteration 4 ⛰:+3.0691e+03 Δ⛰:1.3193e+04 ➽:1.0000e-03
# linear_solver: Iteration 5 ⛰:-2.3756e+02 Δ⛰:3.3066e+03 ➽:1.0000e-03
# linear_solver: Iteration 6 ⛰:-9.1634e+03 Δ⛰:8.9258e+03 ➽:1.0000e-03
# linear_solver: Iteration 7 ⛰:-1.0284e+04 Δ⛰:1.1210e+03 ➽:1.0000e-03
# linear_solver: Iteration 8 ⛰:-1.1374e+04 Δ⛰:1.0895e+03 ➽:1.0000e-03
# linear_solver: Iteration 9 ⛰:-1.1394e+04 Δ⛰:2.0044e+01 ➽:1.0000e-03
# linear_solver: Iteration 10 ⛰:-1.2757e+04 Δ⛰:1.3631e+03 ➽:1.0000e-03
# linear_solver: Iteration 11 ⛰:-1.3195e+04 Δ⛰:4.3834e+02 ➽:1.0000e-03
# linear_solver: Iteration 12 ⛰:-1.3246e+04 Δ⛰:5.0939e+01 ➽:1.0000e-03
# linear_solver: Iteration 13 ⛰:-1.3248e+04 Δ⛰:1.7053e+00 ➽:1.0000e-03
# linear_solver: Iteration 14 ⛰:-1.3354e+04 Δ⛰:1.0601e+02 ➽:1.0000e-03
# linear_solver: Iteration 15 ⛰:-1.3354e+04 Δ⛰:2.1896e-01 ➽:1.0000e-03
# linear_solver: Iteration 16 ⛰:-1.3416e+04 Δ⛰:6.1945e+01 ➽:1.0000e-03
# linear_solver: Iteration 17 ⛰:-1.3420e+04 Δ⛰:3.4443e+00 ➽:1.0000e-03
# linear_solver: Iteration 18 ⛰:-1.3493e+04 Δ⛰:7.3412e+01 ➽:1.0000e-03
# linear_solver: Iteration 19 ⛰:-1.3518e+04 Δ⛰:2.5013e+01 ➽:1.0000e-03
# linear_solver: Iteration 20 ⛰:-1.3566e+04 Δ⛰:4.8471e+01 ➽:1.0000e-03
# linear_solver: Iteration 21 ⛰:-1.3567e+04 Δ⛰:2.0377e-02 ➽:1.0000e-03
# linear_solver: Iteration 22 ⛰:-1.3567e+04 Δ⛰:4.6777e-01 ➽:1.0000e-03
# linear_solver: Iteration 23 ⛰:-1.3568e+04 Δ⛰:8.6068e-01 ➽:1.0000e-03
# linear_solver: Iteration 24 ⛰:-1.3568e+04 Δ⛰:6.4637e-01 ➽:1.0000e-03
# linear_solver: Iteration 25 ⛰:-1.3576e+04 Δ⛰:7.0273e+00 ➽:1.0000e-03
+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:216 |↘|:4.199072e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 36 ⛰:+8.994513e+05 Δ⛰:4.465783e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:222 |↘|:7.621104e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 37 ⛰:+8.949574e+05 Δ⛰:4.493838e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:228 |↘|:4.646358e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 38 ⛰:+8.904940e+05 Δ⛰:4.463382e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:234 |↘|:8.094149e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 39 ⛰:+8.860006e+05 Δ⛰:4.493415e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:240 |↘|:4.673219e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 40 ⛰:+8.815394e+05 Δ⛰:4.461190e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:246 |↘|:6.144964e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 41 ⛰:+8.770632e+05 Δ⛰:4.476253e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:252 |↘|:4.509700e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 42 ⛰:+8.725990e+05 Δ⛰:4.464149e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:258 |↘|:4.686593e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 43 ⛰:+8.681371e+05 Δ⛰:4.461954e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:264 |↘|:4.172606e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 44 ⛰:+8.636718e+05 Δ⛰:4.465274e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:270 |↘|:7.115717e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 45 ⛰:+8.591869e+05 Δ⛰:4.484950e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:276 |↘|:4.437908e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 46 ⛰:+8.547231e+05 Δ⛰:4.463783e+03 🞋:1.000000e-02
# kl_minimizer: →:1.0 ↺:False #∇²:282 |↘|:4.716427e+00 🞋:2.722000e-04
# kl_minimizer: Iteration 47 ⛰:+8.502601e+05 Δ⛰:4.462960e+03 🞋:1.000000e-02

# %% [markdown]
# ### 7. Analyze the Posterior

# %%
import pickle

# Load inference results first to check what was saved
results_dir = Path("my_run")
samples, state = pickle.load(open(results_dir / "last.pkl", "rb"))

# Posterior Mean
posterior_means = jft.mean(samples)

# Predicted signal
pred_signal_mean = signal(posterior_means)

# Predicted data
pred_data_mean = response(posterior_means, pred_signal_mean)

# Residuals
residuals = jnp.array(dataset.data) - jnp.array(pred_data_mean)

# Plot Predicted Signal
fig, axes = plt.subplots(1, dataset.n_channels, figsize=(4*dataset.n_channels, 4))
for i in range(dataset.n_channels):
    axes[i].imshow(pred_signal_mean[i], origin='lower', norm=LogNorm())
    axes[i].set_title(dataset.channel_keys[i])
plt.suptitle("Predicted Signal")
plt.tight_layout()

# Plot Predicted Data
fig, axes = plt.subplots(1, dataset.n_channels, figsize=(4*dataset.n_channels, 4))
for i in range(dataset.n_channels):
    axes[i].imshow(pred_data_mean[i], origin='lower', norm=LogNorm())
    axes[i].set_title(dataset.channel_keys[i])
plt.suptitle("Predicted Data")
plt.tight_layout()

# Plot Actual Data
fig, axes = plt.subplots(1, dataset.n_channels, figsize=(4*dataset.n_channels, 4))
for i, key in enumerate(dataset.channel_keys):
    data, wcs, psf = dataset[key]
    axes[i].imshow(data, norm=LogNorm(), origin='lower')
    axes[i].set_title(key)
plt.suptitle("Data")
plt.tight_layout()
plt.show()

# Plot Residuals
fig, axes = plt.subplots(1, dataset.n_channels, figsize=(4*dataset.n_channels, 4))
for i in range(dataset.n_channels):
    axes[i].imshow(residuals[i], origin='lower')
    axes[i].set_title(dataset.channel_keys[i])
plt.suptitle("Residuals")
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 11
#       8 posterior_means = jft.mean(samples)
#      10 # Predicted signal
# ---> 11 pred_signal_mean = signal(posterior_means)
#      13 # Predicted data
#      14 pred_data_mean = response(posterior_means, pred_signal_mean)
#
# File ~/Desktop/projects/AstroGP/astroprism/src/astroprism/models/signal.py:106, in SignalModel.__call__(self, x)
#     105 def __call__(self, x: dict[str, Any]) -> jnp.ndarray:
# --> 106     base_outputs = self.field({k: x[k] for k in self.field.domain.keys()})
#     108     if self.mixing_mode == "full":
#     109         mixing_matrix = self.mixing_matrix(x)
#
# File ~/Desktop/projects/AstroGP/astroprism/src/astroprism/models/field.py:83, in FieldModel.__call__(self, x)
#      82 def __call__(self, x: dict[str, Any]) -> jnp.ndarray:
# ---> 83     return jax.vmap(self._correlated_fields)(x)
#
#     [... skipping hidden 6 frame]
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/nifty8/re/model.py:228, in Model.__call__(self, *args, **kwargs)
#     227 def __call__(self, *args, **kwargs):
# --> 228     return self._call(*args, **kwargs)
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/nifty8/re/correlated_field.py:913, in CorrelatedFieldMaker.finalize.<locals>.correlated_field(p)
#     912 def correlated_field(p):
# --> 913     ea = outer_amplitude(p)
#     914     cf_h = self.azm(p) * ea * p[self._prefix + "xi"]
#     915     return self._offset_mean + outer_harmonic_transform(cf_h)
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/nifty8/re/correlated_field.py:904, in CorrelatedFieldMaker.finalize.<locals>.outer_amplitude(p)
#     903 def outer_amplitude(p):
# --> 904     outer = expanded_amplitudes[0](p)
#     905     for amp in expanded_amplitudes[1:]:
#     906         # NOTE, the order is important here and must match with the
#     907         # excitations
#     908         # TODO, use functions instead and utilize numpy's casting
#     909         outer = jnp.tensordot(outer, amp(p), axes=0)
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/nifty8/re/correlated_field.py:894, in CorrelatedFieldMaker.finalize.<locals>._mk_expanded_amp.<locals>.expanded_amp(p)
#     893 def expanded_amp(p):
# --> 894     return amp(p)[sub_dom.harmonic_grid.power_distributor]
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/nifty8/re/correlated_field.py:820, in CorrelatedFieldMaker.get_normalized_amplitudes.<locals>._mk_normed_amp.<locals>.normed_amplitude(p)
#     819 def normed_amplitude(p):
# --> 820     return amp(p).at[1:].mul(1.0 / self.azm(p))
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/nifty8/re/correlated_field.py:494, in NonParametricAmplitude.__call__(self, primals)
#     491 ln_spectrum = slope
#     493 if self._deviations is not None:
# --> 494     twolog = self._deviations(primals)
#     495     # Prepend zeromode
#     496     twolog = jnp.concatenate((jnp.zeros((1,)), twolog[:, 0]))
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/nifty8/re/gauss_markov.py:168, in GaussMarkovProcess.__call__(self, x)
#     164 xx = self.x0(x) if isinstance(self.x0, LazyModel) else self.x0
#     165 tmp = {
#     166     k: a(x) if isinstance(a, LazyModel) else a for k, a in self.kwargs.items()
#     167 }
# --> 168 return self.process(xi=xi, x0=xx, dt=self.dt, **tmp)
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/nifty8/re/gauss_markov.py:107, in integrated_wiener_process(xi, x0, sigma, dt, asperity)
#     105 asperity = 0.0 if asperity is None else asperity
#     106 dt = jnp.ones(xi.shape[0]) * dt if _isscalar(dt) else dt
# --> 107 res = (sigma * jnp.sqrt(dt))[:, jnp.newaxis] * xi
#     108 res = res.at[:, 0].mul(jnp.sqrt(dt**2 / 12.0 + asperity))
#     109 res = res.at[:, 0].add(0.5 * dt * res[:, 1])
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/jax/_src/numpy/array_methods.py:1146, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1145 def op(self, *args):
# -> 1146   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/jax/_src/numpy/array_methods.py:609, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     607 args = (other, self) if swap else (self, other)
#     608 if isinstance(other, _accepted_binop_types):
# --> 609   return binary_op(*args)
#     610 # Note: don't use isinstance here, because we don't want to raise for
#     611 # subclasses, e.g. NamedTuple objects that may override operators.
#     612 if type(other) in _rejected_binop_types:
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/jax/_src/numpy/ufunc_api.py:182, in ufunc.__call__(self, out, where, *args)
#     180   raise NotImplementedError(f"where argument of {self}")
#     181 call = self.__static_props['call'] or self._call_vectorized
# --> 182 return call(*args)
#
#     [... skipping hidden 4 frame]
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/jax/_src/numpy/ufuncs.py:1281, in multiply(x, y)
#    1255 """Multiply two arrays element-wise.
#    1256
#    1257 JAX implementation of :obj:`numpy.multiply`. This is a universal function,
#    (...)   1278   Array([ 0, 10, 20, 30], dtype=int32)
#    1279 """
#    1280 x, y = promote_args("multiply", x, y)
# -> 1281 return lax.mul(x, y) if x.dtype != bool else lax.bitwise_and(x, y)
#
#     [... skipping hidden 13 frame]
#
# File ~/Desktop/projects/AstroGP/astroprism/.venv/lib/python3.14/site-packages/jax/_src/lax/lax.py:130, in _try_broadcast_shapes(name, *shapes)
#     128       result_shape.append(non_1s[0])
#     129     else:
# --> 130       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     131                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     132 return tuple(result_shape)
#
# TypeError: mul got incompatible shapes for broadcasting: (84111, 1), (89696, 2).

# %% [markdown]
# ## Summary
#
# In this tutorial, you learned the complete AstroPFM pipeline:
#
# | Step | Component | Purpose |
# |------|-----------|---------|
# | 1 | Dataset | Load and organize multi-channel data |
# | 2 | MixtureGP | Gaussian Process prior for sky model |
# | 3 | InstrumentResponse | Reprojection + PSF convolution |
# | 4 | NoiseModel | Heteroscedastic noise modeling |
# | 5 | ForwardModel | Combine all components |
# | 6 | Likelihood & Inference | Connect model to data and perform Bayesian inference|
# | 7 | Analysis | Visualize and interpret results |
