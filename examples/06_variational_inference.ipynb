# %% [markdown]
# # AstroPrism Tutorial: Likelihood & Variational Inference
#
# The **likelihood** connects our forward model to observed data using a Variable Covariance Gaussian:
#
# $$\mathcal{L}(d | \theta) = \prod_i \mathcal{N}(d_i \,|\, \mu_i(\theta), \sigma_i^2(\theta))$$
#
# Where:
# - $d_i$ = observed pixel value
# - $\mu_i(\theta)$ = model prediction (from instrument response)
# - $\sigma_i(\theta)$ = noise std (from noise model)
# - $\theta$ = all model parameters
#
# Given the likelihood and prior $p(\theta)$, we want the posterior:
#
# $$p(\theta | d) \propto \mathcal{L}(d | \theta) \, p(\theta)$$
#
# Since this is intractable, we use **Variational Inference (VI)** to approximate it with a simpler distribution $q(\theta)$ by minimizing the KL divergence:
#
# $$\text{KL}(q \| p) = \mathbb{E}_q \left[ \log q(\theta) - \log p(\theta | d) \right]$$
#
# AstroPrism uses NIFTy8's **Geometric VI (GeoVI)**, which leverages the geometry of the parameter space for efficient optimization.

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import warnings
from astropy.utils.exceptions import AstropyWarning
import jax

warnings.filterwarnings('ignore', category=AstropyWarning)

# %% [markdown]
# ## Demonstration

# %%
# Load Dataset
from astroprism.io import load_dataset, SingleInstrumentDataset
path = "../data/tutorial/jwst_miri_cutout/"
dataset = load_dataset(path=path, instrument="JWST_MIRI", extension="fits")
print(dataset.summary())

# GP Sky Model
from astroprism.models.gp import SpatialGP, MixtureGP
spatial_gp = SpatialGP(
    n_channels=len(dataset),
    shape=dataset.shapes[0],
    distances=dataset.pixel_scales[0],
)
mixture = MixtureGP(spatial_gps=spatial_gp)

# Instrument Response Model
from astroprism.models.response import InstrumentResponse
response = InstrumentResponse(
    dataset=dataset,
    signal_wcs=dataset.wcs[0],
    signal_shape=dataset.shapes[0],
)

# Noise Model
from astroprism.models.noise import NoiseModel
noise = NoiseModel(n_channels=len(dataset))

# Forward Model
from astroprism.models.forward import ForwardModel
model = ForwardModel(mixture, response, noise)
print("ForwardModel domain keys:", list(model.domain.keys()))
# Out:
# SingleInstrumentDataset Summary:
# --------------------------------
# Number of channels: 4
# Channel keys: ['F1000W_full', 'F1130W_full', 'F2100W_full', 'F770W_full']
# Channel shapes: [(600, 600), (600, 600), (600, 600), (600, 600)]
# Pixel scales: [(0.11091449975820492, 0.1109144997630491), (0.11091449949791077, 0.11091449946799463), (0.11091449907273217, 0.11091449905375952), (0.11091450012231652, 0.11091450010349585)]
#
# ForwardModel domain keys: ['zeromode', 'fluctuations', 'loglogavgslope', 'spectrum', 'flexibility', 'xi', 'mixture_matrix', 'mixing_offset', 'psf_sigma', 'psf_rotation', 'background_std', 'poisson_scale']

# %% [markdown]
# ### Build Likelihood
#
# The `build_likelihood` function constructs the likelihood from the dataset, forward model, and an optional mask to exclude bad pixels (e.g., detector edges, cosmic rays).

# %%
# Imports
from astroprism.models.likelihood import build_likelihood

# Build likelihood: Combines data, model, and mask (readout)
likelihood = build_likelihood(dataset, model, mask=dataset.readout)

# %% [markdown]
# ### Run Variational Inference
#
# The `run_inference` function runs GeoVI optimization, returning posterior samples and the optimizer state.

# %%
# Imports
from astroprism.inference.vi import run_inference

# Run inference: Optimizes the likelihood 
samples, state = run_inference(
    likelihood, 
    n_iterations=10,   # number of iterations
    n_samples=2,      # number of samples
    seed=42,
    output_directory="tutorial_results"
)
# Out:
# /opt/homebrew/Cellar/python@3.14/3.14.0_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/genericpath.py:39: RuntimeWarning: bool is used as a file descriptor
#   st = os.stat(path)
# OPTIMIZE_KL: Starting 0001
# Starting VI optimization: 2 iterations, 2 samples.
# linear_solver: Iteration 0 ⛰:+1.6211e+10 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:+9.4390e+08 Δ⛰:1.5267e+10 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:+4.6147e+08 Δ⛰:4.8243e+08 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:+1.4064e+08 Δ⛰:3.2083e+08 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:+5.6275e+07 Δ⛰:8.4363e+07 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:+5.1143e+07 Δ⛰:5.1326e+06 ➽:1.0000e-04
# linear_solver: Iteration 6 ⛰:+3.6643e+07 Δ⛰:1.4499e+07 ➽:1.0000e-04
# linear_solver: Iteration 7 ⛰:+3.4348e+07 Δ⛰:2.2959e+06 ➽:1.0000e-04
# linear_solver: Iteration 8 ⛰:+2.4230e+07 Δ⛰:1.0117e+07 ➽:1.0000e-04
# linear_solver: Iteration 9 ⛰:+1.1515e+07 Δ⛰:1.2715e+07 ➽:1.0000e-04
# linear_solver: Iteration 10 ⛰:+1.0501e+07 Δ⛰:1.0141e+06 ➽:1.0000e-04
# linear_solver: Iteration 11 ⛰:+1.0494e+07 Δ⛰:7.0885e+03 ➽:1.0000e-04
# linear_solver: Iteration 12 ⛰:+7.3519e+06 Δ⛰:3.1421e+06 ➽:1.0000e-04
# linear_solver: Iteration 13 ⛰:+7.2212e+06 Δ⛰:1.3075e+05 ➽:1.0000e-04
# linear_solver: Iteration 14 ⛰:+4.2630e+06 Δ⛰:2.9582e+06 ➽:1.0000e-04
# linear_solver: Iteration 15 ⛰:+3.2381e+06 Δ⛰:1.0249e+06 ➽:1.0000e-04
# linear_solver: Iteration 16 ⛰:+3.2271e+06 Δ⛰:1.0957e+04 ➽:1.0000e-04
# linear_solver: Iteration 17 ⛰:+3.1262e+06 Δ⛰:1.0094e+05 ➽:1.0000e-04
# linear_solver: Iteration 18 ⛰:+2.4813e+06 Δ⛰:6.4491e+05 ➽:1.0000e-04
# linear_solver: Iteration 19 ⛰:+2.4651e+06 Δ⛰:1.6162e+04 ➽:1.0000e-04
# linear_solver: Iteration 20 ⛰:+2.0228e+06 Δ⛰:4.4230e+05 ➽:1.0000e-04
# linear_solver: Iteration 21 ⛰:+1.9871e+06 Δ⛰:3.5729e+04 ➽:1.0000e-04
# linear_solver: Iteration 85 ⛰:-5.8067e+05 Δ⛰:3.6262e+04 ➽:1.0000e-04
# linear_solver: Iteration 86 ⛰:-5.8079e+05 Δ⛰:1.2265e+02 ➽:1.0000e-04
# linear_solver: Iteration 87 ⛰:-5.8726e+05 Δ⛰:6.4711e+03 ➽:1.0000e-04
# linear_solver: Iteration 88 ⛰:-5.8811e+05 Δ⛰:8.4714e+02 ➽:1.0000e-04
# linear_solver: Iteration 89 ⛰:-5.9835e+05 Δ⛰:1.0239e+04 ➽:1.0000e-04
# linear_solver: Iteration 90 ⛰:-6.1932e+05 Δ⛰:2.0966e+04 ➽:1.0000e-04
# linear_solver: Iteration 91 ⛰:-6.2723e+05 Δ⛰:7.9109e+03 ➽:1.0000e-04
# linear_solver: Iteration 92 ⛰:-6.2775e+05 Δ⛰:5.2550e+02 ➽:1.0000e-04
# linear_solver: Iteration 93 ⛰:-6.2776e+05 Δ⛰:3.9561e+00 ➽:1.0000e-04
# linear_solver: Iteration 94 ⛰:-6.2892e+05 Δ⛰:1.1636e+03 ➽:1.0000e-04
# linear_solver: Iteration 95 ⛰:-6.5832e+05 Δ⛰:2.9397e+04 ➽:1.0000e-04
# linear_solver: Iteration 96 ⛰:-6.5882e+05 Δ⛰:4.9969e+02 ➽:1.0000e-04
# linear_solver: Iteration 97 ⛰:-6.5890e+05 Δ⛰:8.6166e+01 ➽:1.0000e-04
# linear_solver: Iteration 98 ⛰:-6.6335e+05 Δ⛰:4.4482e+03 ➽:1.0000e-04
# linear_solver: Iteration 99 ⛰:-6.6634e+05 Δ⛰:2.9929e+03 ➽:1.0000e-04
# linear_solver: Iteration ✖✖✖ (100) ⛰:-6.8225e+05 Δ⛰:1.5910e+04 ➽:1.0000e-04
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:1.599482e+04 🞋:2.112940e+02
# nonlinear_solver: Iteration 1 ⛰:+1.832861e+17 Δ⛰:1.452176e+18
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:5.505478e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 2 ⛰:+4.219905e+16 Δ⛰:1.410871e+17
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:3.729073e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 3 ⛰:+1.013726e+16 Δ⛰:3.206180e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:1.035268e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 4 ⛰:+2.668867e+15 Δ⛰:7.468388e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:4.910059e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 5 ⛰:+8.244836e+14 Δ⛰:1.844383e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:36 |↘|:2.426266e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 6 ⛰:+3.439649e+14 Δ⛰:4.805187e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:42 |↘|:2.319306e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 7 ⛰:+2.199213e+14 Δ⛰:1.240436e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:48 |↘|:2.643099e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 8 ⛰:+1.606694e+14 Δ⛰:5.925189e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:54 |↘|:4.763864e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 9 ⛰:+1.353118e+14 Δ⛰:2.535764e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:60 |↘|:2.074278e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 10 ⛰:+1.226923e+14 Δ⛰:1.261952e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:1.982737e+04 🞋:2.112940e+02
# nonlinear_solver: Iteration 1 ⛰:+1.456828e+17 Δ⛰:3.758847e+18
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:7.819964e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 2 ⛰:+3.119247e+16 Δ⛰:1.144903e+17
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:3.770709e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 3 ⛰:+7.249467e+15 Δ⛰:2.394300e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:1.658200e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 4 ⛰:+1.775565e+15 Δ⛰:5.473902e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:6.796777e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 5 ⛰:+4.906600e+14 Δ⛰:1.284904e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:36 |↘|:3.473967e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 6 ⛰:+1.865678e+14 Δ⛰:3.040923e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:42 |↘|:1.457783e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 7 ⛰:+1.106390e+14 Δ⛰:7.592873e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:9.768938e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 1 ⛰:+3.421486e+17 Δ⛰:1.726657e+18
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:2.770001e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 2 ⛰:+7.707495e+16 Δ⛰:2.650736e+17
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:1.022732e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 3 ⛰:+1.842648e+16 Δ⛰:5.864848e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:4.052994e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 4 ⛰:+4.511050e+15 Δ⛰:1.391543e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:1.939521e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 5 ⛰:+1.121505e+15 Δ⛰:3.389545e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:1.697145e+04 🞋:2.112940e+02
# nonlinear_solver: Iteration 1 ⛰:+2.350826e+17 Δ⛰:1.089524e+18
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:5.574496e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 2 ⛰:+5.329316e+16 Δ⛰:1.817894e+17
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:2.414067e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 3 ⛰:+1.279505e+16 Δ⛰:4.049811e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:9.249838e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 4 ⛰:+3.161776e+15 Δ⛰:9.633270e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:5.635083e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 5 ⛰:+7.889187e+14 Δ⛰:2.372857e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:36 |↘|:1.712950e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 6 ⛰:+2.038170e+14 Δ⛰:5.851017e+14
# kl_minimizer: WARNING: Energy would increase; aborting
# OPTIMIZE_KL: Iteration 0001 ⛰:+1.4201e+11
# OPTIMIZE_KL: #(Nonlinear sampling steps) (10, 7, 5, 6)
# OPTIMIZE_KL: #(KL minimization steps) 1
# OPTIMIZE_KL: Likelihood residual(s):
# 'reduced χ²:   2e+05± 7.6e+04, avg:   +3e+01±     6.2, #dof:1439812'
#
# OPTIMIZE_KL: Prior residual(s):
# background_std          :: 'reduced χ²:     1.6±     1.0, avg:     -0.1±    0.47, #dof:      4'
# flexibility             :: 'reduced χ²:     1.9±    0.85, avg:    -0.48±    0.21, #dof:      4'
# fluctuations            :: 'reduced χ²:     3.3±     0.7, avg:     -1.1±    0.11, #dof:      4'
# loglogavgslope          :: 'reduced χ²:     1.6±    0.68, avg:    -0.17±    0.31, #dof:      4'
# mixing_offset           :: 'reduced χ²:     2.2±     1.0, avg:    -0.66±    0.69, #dof:      4'
# mixture_matrix          :: 'reduced χ²:     1.3±    0.46, avg:    +0.25±    0.18, #dof:     16'
# poisson_scale           :: 'reduced χ²:    0.39±   0.072, avg:   +0.064±   0.074, #dof:      4'
# psf_rotation            :: 'reduced χ²:     2.3±    0.57, avg:     -0.3±    0.65, #dof:      4'
# psf_sigma               :: 'reduced χ²:     2.1±     1.3, avg:    +0.22±    0.39, #dof:      4'
# spectrum                :: 'reduced χ²:     2.0±  0.0013, avg: -0.00092±   0.001, #dof: 672888'
# xi                      :: 'reduced χ²:     2.0±  0.0004, avg:  +0.0014± 0.00056, #dof:1440000'
# zeromode                :: 'reduced χ²:     1.5±    0.89, avg:   -0.031±    0.73, #dof:      4'
#
#
# OPTIMIZE_KL: Starting 0002
# linear_solver: Iteration 0 ⛰:+9.5428e+09 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:+4.5359e+08 Δ⛰:9.0892e+09 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:+2.3649e+08 Δ⛰:2.1711e+08 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:+1.1863e+08 Δ⛰:1.1785e+08 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:+8.0355e+07 Δ⛰:3.8280e+07 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:+4.6633e+07 Δ⛰:3.3722e+07 ➽:1.0000e-04
# linear_solver: Iteration 6 ⛰:+3.5328e+07 Δ⛰:1.1305e+07 ➽:1.0000e-04
# linear_solver: Iteration 7 ⛰:+3.4418e+07 Δ⛰:9.0972e+05 ➽:1.0000e-04
# linear_solver: Iteration 8 ⛰:+1.9764e+07 Δ⛰:1.4654e+07 ➽:1.0000e-04
# linear_solver: Iteration 9 ⛰:+1.1253e+07 Δ⛰:8.5111e+06 ➽:1.0000e-04
# linear_solver: Iteration 10 ⛰:+8.5338e+06 Δ⛰:2.7191e+06 ➽:1.0000e-04
# linear_solver: Iteration 11 ⛰:+8.5101e+06 Δ⛰:2.3641e+04 ➽:1.0000e-04
# linear_solver: Iteration 12 ⛰:+6.5741e+06 Δ⛰:1.9361e+06 ➽:1.0000e-04
# linear_solver: Iteration 13 ⛰:+6.5426e+06 Δ⛰:3.1468e+04 ➽:1.0000e-04
# linear_solver: Iteration 14 ⛰:+4.8917e+06 Δ⛰:1.6509e+06 ➽:1.0000e-04
# linear_solver: Iteration 15 ⛰:+4.7720e+06 Δ⛰:1.1967e+05 ➽:1.0000e-04
# linear_solver: Iteration 16 ⛰:+4.3894e+06 Δ⛰:3.8258e+05 ➽:1.0000e-04
# linear_solver: Iteration 17 ⛰:+3.3949e+06 Δ⛰:9.9449e+05 ➽:1.0000e-04
# linear_solver: Iteration 18 ⛰:+2.5965e+06 Δ⛰:7.9843e+05 ➽:1.0000e-04
# linear_solver: Iteration 19 ⛰:+2.5387e+06 Δ⛰:5.7821e+04 ➽:1.0000e-04
# linear_solver: Iteration 20 ⛰:+2.0761e+06 Δ⛰:4.6258e+05 ➽:1.0000e-04
# linear_solver: Iteration 21 ⛰:+2.0306e+06 Δ⛰:4.5465e+04 ➽:1.0000e-04
# linear_solver: Iteration 22 ⛰:+1.8328e+06 Δ⛰:1.9788e+05 ➽:1.0000e-04
# linear_solver: Iteration 23 ⛰:+1.6991e+06 Δ⛰:1.3370e+05 ➽:1.0000e-04
# linear_solver: Iteration 24 ⛰:+1.6668e+06 Δ⛰:3.2280e+04 ➽:1.0000e-04
# linear_solver: Iteration 25 ⛰:+1.4810e+06 Δ⛰:1.8580e+05 ➽:1.0000e-04
# linear_solver: Iteration 26 ⛰:+1.2055e+06 Δ⛰:2.7544e+05 ➽:1.0000e-04
# linear_solver: Iteration 27 ⛰:+1.1505e+06 Δ⛰:5.5080e+04 ➽:1.0000e-04
# linear_solver: Iteration 28 ⛰:+9.0083e+05 Δ⛰:2.4963e+05 ➽:1.0000e-04
# linear_solver: Iteration 29 ⛰:+8.8515e+05 Δ⛰:1.5678e+04 ➽:1.0000e-04
# linear_solver: Iteration 30 ⛰:+8.7317e+05 Δ⛰:1.1980e+04 ➽:1.0000e-04
# linear_solver: Iteration 31 ⛰:+7.5522e+05 Δ⛰:1.1795e+05 ➽:1.0000e-04
# linear_solver: Iteration 32 ⛰:+7.5384e+05 Δ⛰:1.3844e+03 ➽:1.0000e-04
# linear_solver: Iteration 33 ⛰:+7.4302e+05 Δ⛰:1.0813e+04 ➽:1.0000e-04
# linear_solver: Iteration 34 ⛰:+7.2273e+05 Δ⛰:2.0291e+04 ➽:1.0000e-04
# linear_solver: Iteration 35 ⛰:+6.3477e+05 Δ⛰:8.7964e+04 ➽:1.0000e-04
# linear_solver: Iteration 36 ⛰:+5.6767e+05 Δ⛰:6.7099e+04 ➽:1.0000e-04
# linear_solver: Iteration 37 ⛰:+5.5972e+05 Δ⛰:7.9475e+03 ➽:1.0000e-04
# linear_solver: Iteration 38 ⛰:+5.4132e+05 Δ⛰:1.8407e+04 ➽:1.0000e-04
# linear_solver: Iteration 39 ⛰:+3.6991e+05 Δ⛰:1.7140e+05 ➽:1.0000e-04
# linear_solver: Iteration 40 ⛰:+3.6986e+05 Δ⛰:5.5176e+01 ➽:1.0000e-04
# linear_solver: Iteration 41 ⛰:+2.0688e+05 Δ⛰:1.6298e+05 ➽:1.0000e-04
# linear_solver: Iteration 42 ⛰:+2.0291e+05 Δ⛰:3.9670e+03 ➽:1.0000e-04
# linear_solver: Iteration 43 ⛰:+2.0027e+05 Δ⛰:2.6435e+03 ➽:1.0000e-04
# linear_solver: Iteration 44 ⛰:+5.6766e+04 Δ⛰:1.4350e+05 ➽:1.0000e-04
# linear_solver: Iteration 45 ⛰:+5.6720e+04 Δ⛰:4.6170e+01 ➽:1.0000e-04
# linear_solver: Iteration 46 ⛰:+2.7559e+04 Δ⛰:2.9160e+04 ➽:1.0000e-04
# linear_solver: Iteration 47 ⛰:+2.3140e+04 Δ⛰:4.4194e+03 ➽:1.0000e-04
# linear_solver: Iteration 48 ⛰:+2.0532e+04 Δ⛰:2.6076e+03 ➽:1.0000e-04
# linear_solver: Iteration 49 ⛰:-5.5826e+04 Δ⛰:7.6358e+04 ➽:1.0000e-04
# linear_solver: Iteration 50 ⛰:-5.5847e+04 Δ⛰:2.1962e+01 ➽:1.0000e-04
# linear_solver: Iteration 51 ⛰:-1.7194e+05 Δ⛰:1.1609e+05 ➽:1.0000e-04
# linear_solver: Iteration 52 ⛰:-1.7246e+05 Δ⛰:5.2262e+02 ➽:1.0000e-04
# linear_solver: Iteration 53 ⛰:-1.7425e+05 Δ⛰:1.7836e+03 ➽:1.0000e-04
# linear_solver: Iteration 82 ⛰:-5.8277e+05 Δ⛰:2.6688e+02 ➽:1.0000e-04
# linear_solver: Iteration 83 ⛰:-5.8835e+05 Δ⛰:5.5871e+03 ➽:1.0000e-04
# linear_solver: Iteration 84 ⛰:-5.8837e+05 Δ⛰:1.4690e+01 ➽:1.0000e-04
# linear_solver: Iteration 85 ⛰:-6.1484e+05 Δ⛰:2.6475e+04 ➽:1.0000e-04
# linear_solver: Iteration 86 ⛰:-6.1591e+05 Δ⛰:1.0726e+03 ➽:1.0000e-04
# linear_solver: Iteration 87 ⛰:-6.2094e+05 Δ⛰:5.0289e+03 ➽:1.0000e-04
# linear_solver: Iteration 88 ⛰:-6.2095e+05 Δ⛰:1.5690e+00 ➽:1.0000e-04
# linear_solver: Iteration 89 ⛰:-6.4062e+05 Δ⛰:1.9672e+04 ➽:1.0000e-04
# linear_solver: Iteration 90 ⛰:-6.6243e+05 Δ⛰:2.1813e+04 ➽:1.0000e-04
# linear_solver: Iteration 91 ⛰:-6.6500e+05 Δ⛰:2.5731e+03 ➽:1.0000e-04
# linear_solver: Iteration 92 ⛰:-6.6845e+05 Δ⛰:3.4496e+03 ➽:1.0000e-04
# linear_solver: Iteration 93 ⛰:-6.6845e+05 Δ⛰:1.5325e+00 ➽:1.0000e-04
# linear_solver: Iteration 94 ⛰:-6.6937e+05 Δ⛰:9.1339e+02 ➽:1.0000e-04
# linear_solver: Iteration 95 ⛰:-6.7600e+05 Δ⛰:6.6362e+03 ➽:1.0000e-04
# linear_solver: Iteration 96 ⛰:-7.0200e+05 Δ⛰:2.5996e+04 ➽:1.0000e-04
# linear_solver: Iteration 97 ⛰:-7.0200e+05 Δ⛰:5.4498e+00 ➽:1.0000e-04
# linear_solver: Iteration 98 ⛰:-7.0259e+05 Δ⛰:5.8129e+02 ➽:1.0000e-04
# linear_solver: Iteration 99 ⛰:-7.0263e+05 Δ⛰:4.2582e+01 ➽:1.0000e-04
# linear_solver: Iteration ✖✖✖ (100) ⛰:-7.0395e+05 Δ⛰:1.3193e+03 ➽:1.0000e-04
# linear_solver: Iteration 0 ⛰:+3.6346e+10 Δ⛰:inf ➽:1.0000e-04
# linear_solver: Iteration 1 ⛰:+3.0505e+09 Δ⛰:3.3295e+10 ➽:1.0000e-04
# linear_solver: Iteration 2 ⛰:+5.8988e+08 Δ⛰:2.4606e+09 ➽:1.0000e-04
# linear_solver: Iteration 3 ⛰:+1.2408e+08 Δ⛰:4.6580e+08 ➽:1.0000e-04
# linear_solver: Iteration 4 ⛰:+7.5931e+07 Δ⛰:4.8151e+07 ➽:1.0000e-04
# linear_solver: Iteration 5 ⛰:+3.8221e+07 Δ⛰:3.7710e+07 ➽:1.0000e-04
# linear_solver: Iteration 6 ⛰:+3.4403e+07 Δ⛰:3.8172e+06 ➽:1.0000e-04
# linear_solver: Iteration 7 ⛰:+2.5741e+07 Δ⛰:8.6621e+06 ➽:1.0000e-04
# linear_solver: Iteration 63 ⛰:-3.7674e+05 Δ⛰:2.1226e+04 ➽:1.0000e-04
# linear_solver: Iteration 64 ⛰:-3.9800e+05 Δ⛰:2.1268e+04 ➽:1.0000e-04
# linear_solver: Iteration 65 ⛰:-3.9807e+05 Δ⛰:6.4731e+01 ➽:1.0000e-04
# linear_solver: Iteration 66 ⛰:-4.3958e+05 Δ⛰:4.1515e+04 ➽:1.0000e-04
# linear_solver: Iteration 67 ⛰:-4.4674e+05 Δ⛰:7.1538e+03 ➽:1.0000e-04
# linear_solver: Iteration 68 ⛰:-4.8234e+05 Δ⛰:3.5601e+04 ➽:1.0000e-04
# linear_solver: Iteration 69 ⛰:-4.8271e+05 Δ⛰:3.7062e+02 ➽:1.0000e-04
# linear_solver: Iteration 70 ⛰:-4.8648e+05 Δ⛰:3.7702e+03 ➽:1.0000e-04
# linear_solver: Iteration 71 ⛰:-4.8656e+05 Δ⛰:7.7422e+01 ➽:1.0000e-04
# linear_solver: Iteration 72 ⛰:-4.8729e+05 Δ⛰:7.3550e+02 ➽:1.0000e-04
# linear_solver: Iteration 73 ⛰:-4.9653e+05 Δ⛰:9.2386e+03 ➽:1.0000e-04
# linear_solver: Iteration 74 ⛰:-5.1983e+05 Δ⛰:2.3300e+04 ➽:1.0000e-04
# linear_solver: Iteration 75 ⛰:-5.4122e+05 Δ⛰:2.1391e+04 ➽:1.0000e-04
# linear_solver: Iteration 76 ⛰:-5.4416e+05 Δ⛰:2.9356e+03 ➽:1.0000e-04
# linear_solver: Iteration 77 ⛰:-5.4777e+05 Δ⛰:3.6147e+03 ➽:1.0000e-04
# linear_solver: Iteration 78 ⛰:-5.6165e+05 Δ⛰:1.3874e+04 ➽:1.0000e-04
# linear_solver: Iteration 79 ⛰:-5.8231e+05 Δ⛰:2.0659e+04 ➽:1.0000e-04
# linear_solver: Iteration 80 ⛰:-5.8247e+05 Δ⛰:1.5987e+02 ➽:1.0000e-04
# linear_solver: Iteration 81 ⛰:-5.8923e+05 Δ⛰:6.7690e+03 ➽:1.0000e-04
# linear_solver: Iteration 82 ⛰:-5.9164e+05 Δ⛰:2.4097e+03 ➽:1.0000e-04
# linear_solver: Iteration 83 ⛰:-5.9302e+05 Δ⛰:1.3800e+03 ➽:1.0000e-04
# linear_solver: Iteration 84 ⛰:-5.9313e+05 Δ⛰:1.0617e+02 ➽:1.0000e-04
# linear_solver: Iteration 85 ⛰:-6.3225e+05 Δ⛰:3.9123e+04 ➽:1.0000e-04
# linear_solver: Iteration 86 ⛰:-6.3261e+05 Δ⛰:3.5503e+02 ➽:1.0000e-04
# linear_solver: Iteration 87 ⛰:-6.3697e+05 Δ⛰:4.3651e+03 ➽:1.0000e-04
# linear_solver: Iteration 88 ⛰:-6.3812e+05 Δ⛰:1.1478e+03 ➽:1.0000e-04
# linear_solver: Iteration 89 ⛰:-6.3960e+05 Δ⛰:1.4759e+03 ➽:1.0000e-04
# linear_solver: Iteration 90 ⛰:-6.4106e+05 Δ⛰:1.4593e+03 ➽:1.0000e-04
# linear_solver: Iteration 91 ⛰:-6.7270e+05 Δ⛰:3.1647e+04 ➽:1.0000e-04
# linear_solver: Iteration 92 ⛰:-6.7274e+05 Δ⛰:3.3302e+01 ➽:1.0000e-04
# linear_solver: Iteration 93 ⛰:-6.7278e+05 Δ⛰:4.0813e+01 ➽:1.0000e-04
# linear_solver: Iteration 94 ⛰:-6.7856e+05 Δ⛰:5.7838e+03 ➽:1.0000e-04
# linear_solver: Iteration 95 ⛰:-6.8121e+05 Δ⛰:2.6477e+03 ➽:1.0000e-04
# linear_solver: Iteration 96 ⛰:-6.9503e+05 Δ⛰:1.3819e+04 ➽:1.0000e-04
# linear_solver: Iteration 97 ⛰:-7.0353e+05 Δ⛰:8.5047e+03 ➽:1.0000e-04
# linear_solver: Iteration 98 ⛰:-7.0380e+05 Δ⛰:2.6826e+02 ➽:1.0000e-04
# linear_solver: Iteration 99 ⛰:-7.0434e+05 Δ⛰:5.4210e+02 ➽:1.0000e-04
# linear_solver: Iteration ✖✖✖ (100) ⛰:-7.2896e+05 Δ⛰:2.4621e+04 ➽:1.0000e-04
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:1.558559e+04 🞋:2.112940e+02
# nonlinear_solver: Iteration 1 ⛰:+4.420313e+17 Δ⛰:2.232566e+18
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:4.565716e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 2 ⛰:+9.964613e+16 Δ⛰:3.423852e+17
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:2.011695e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 3 ⛰:+2.384865e+16 Δ⛰:7.579748e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:9.447287e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 4 ⛰:+5.847598e+15 Δ⛰:1.800105e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:4.385634e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 5 ⛰:+1.452499e+15 Δ⛰:4.395099e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:36 |↘|:1.794688e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 6 ⛰:+3.650689e+14 Δ⛰:1.087430e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:1.672716e+04 🞋:2.112940e+02
# nonlinear_solver: Iteration 1 ⛰:+3.811697e+17 Δ⛰:1.875768e+18
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:5.571118e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 2 ⛰:+8.621005e+16 Δ⛰:2.949597e+17
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:2.334267e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 3 ⛰:+2.061340e+16 Δ⛰:6.559665e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:1.222719e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 4 ⛰:+5.054573e+15 Δ⛰:1.555883e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:6.673472e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 5 ⛰:+1.258353e+15 Δ⛰:3.796220e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:36 |↘|:4.200166e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 6 ⛰:+3.205775e+14 Δ⛰:9.377754e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:42 |↘|:2.163314e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 7 ⛰:+8.799344e+13 Δ⛰:2.325841e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:48 |↘|:3.020412e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 8 ⛰:+2.943333e+13 Δ⛰:5.856011e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:54 |↘|:2.731915e+01 🞋:2.112940e+02
# nonlinear_solver: Iteration 9 ⛰:+1.513759e+13 Δ⛰:1.429574e+13
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:1.063487e+04 🞋:2.112940e+02
# nonlinear_solver: Iteration 1 ⛰:+1.961765e+18 Δ⛰:4.366747e+18
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:7.673439e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 2 ⛰:+5.721336e+17 Δ⛰:1.389631e+18
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:4.792303e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 3 ⛰:+1.577190e+17 Δ⛰:4.144146e+17
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:2.677586e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 4 ⛰:+4.172589e+16 Δ⛰:1.159931e+17
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:1.351106e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 5 ⛰:+1.076611e+16 Δ⛰:3.095977e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:36 |↘|:5.403307e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 6 ⛰:+2.746803e+15 Δ⛰:8.019311e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:42 |↘|:2.671022e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 7 ⛰:+7.060323e+14 Δ⛰:2.040771e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:48 |↘|:9.392378e+01 🞋:2.112940e+02
# nonlinear_solver: Iteration 8 ⛰:+1.825462e+14 Δ⛰:5.234861e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:06 |↘|:5.768591e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 1 ⛰:+8.018480e+17 Δ⛰:1.919026e+18
# nonlinear_solver: →:1.0 ↺:False #∇²:12 |↘|:4.172074e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 2 ⛰:+2.232916e+17 Δ⛰:5.785564e+17
# nonlinear_solver: →:1.0 ↺:False #∇²:18 |↘|:3.527291e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 3 ⛰:+5.962813e+16 Δ⛰:1.636635e+17
# nonlinear_solver: →:1.0 ↺:False #∇²:24 |↘|:2.888140e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 4 ⛰:+1.540888e+16 Δ⛰:4.421925e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:30 |↘|:1.124672e+03 🞋:2.112940e+02
# nonlinear_solver: Iteration 5 ⛰:+3.932264e+15 Δ⛰:1.147661e+16
# nonlinear_solver: →:1.0 ↺:False #∇²:36 |↘|:6.867140e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 6 ⛰:+9.945638e+14 Δ⛰:2.937700e+15
# nonlinear_solver: →:1.0 ↺:False #∇²:42 |↘|:4.904943e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 7 ⛰:+2.535311e+14 Δ⛰:7.410327e+14
# nonlinear_solver: →:1.0 ↺:False #∇²:48 |↘|:2.046642e+02 🞋:2.112940e+02
# nonlinear_solver: Iteration 8 ⛰:+6.656797e+13 Δ⛰:1.869631e+14
# kl_minimizer: WARNING: Energy would increase; aborting
# OPTIMIZE_KL: Iteration 0002 ⛰:+7.8016e+10
# OPTIMIZE_KL: #(Nonlinear sampling steps) (6, 9, 8, 8)
# OPTIMIZE_KL: #(KL minimization steps) 1
# OPTIMIZE_KL: Likelihood residual(s):
# 'reduced χ²: 1.1e+05±   3e+04, avg: +2.2e+01±     1.9, #dof:1439812'
#
# OPTIMIZE_KL: Prior residual(s):
# background_std          :: 'reduced χ²:     1.0±    0.86, avg:     -0.1±    0.82, #dof:      4'
# flexibility             :: 'reduced χ²:     2.3±    0.68, avg:    -0.48±    0.39, #dof:      4'
# fluctuations            :: 'reduced χ²:     3.8±     1.1, avg:     -1.1±    0.29, #dof:      4'
# loglogavgslope          :: 'reduced χ²:     1.5±    0.66, avg:    -0.17±    0.18, #dof:      4'
# mixing_offset           :: 'reduced χ²:     2.4±     1.0, avg:    -0.68±     0.3, #dof:      4'
# mixture_matrix          :: 'reduced χ²:     1.1±    0.26, avg:    +0.22±   0.083, #dof:     16'
# poisson_scale           :: 'reduced χ²:    0.38±    0.11, avg:   +0.061±    0.03, #dof:      4'
# psf_rotation            :: 'reduced χ²:     2.3±     1.5, avg:     -0.3±     0.3, #dof:      4'
# psf_sigma               :: 'reduced χ²:     1.6±    0.61, avg:    +0.22±    0.16, #dof:      4'
# spectrum                :: 'reduced χ²:     2.0±  0.0018, avg: -0.00092± 0.00066, #dof: 672888'
# xi                      :: 'reduced χ²:     2.0±   0.001, avg:  +0.0014± 0.00059, #dof:1440000'
# zeromode                :: 'reduced χ²:     2.0±     1.2, avg:   -0.027±   0.088, #dof:      4'
